# %%
import pandas as pd
import re
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import linear_model
import numpy as np
from sklearn.metrics import r2_score
from scipy import stats

# %%
amazon_sales = pd.read_csv('amazon.csv')

# %% [markdown]
# I got this dataset from kaggle
#
# Sources: https://www.kaggle.com/datasets/karkavelrajaj/amazon-sales-dataset?resource=download

# %% [markdown]
# # Data Cleaning and Preparation

# %% [markdown]
# The methods used to clean and prepare the data are as listed below:
# 1. Convert Data Types
# 2. Filling Missing Data
# 3. Checking Duplicates Data
# 4. Creating New Columns

# %%
amazon_sales.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 3  Computers&Accessories|Accessories&Peripherals|...             ₹329
# 4  Computers&Accessories|Accessories&Peripherals|...             ₹154
#
#   actual_price discount_percentage rating rating_count  \
# 0       ₹1,099                 64%    4.2       24,269
# 1         ₹349                 43%    4.0       43,994
# 2       ₹1,899                 90%    3.9        7,928
# 3         ₹699                 53%    4.2       94,363
# 4         ₹399                 61%    4.2       16,905
#
#                                        about_product  \
# 0  High Compatibility : Compatible With iPhone 12...
# 1  Compatible with all Type C enabled devices, be...
# 2  【 Fast Charger& Data Sync】-With built-in safet...
# 3  The boAt Deuce USB 300 2 in 1 cable is compati...
# 4  [CHARGE & SYNC FUNCTION]- This cable comes wit...
#
#                                              user_id  \
# 0  AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...
# 1  AECPFYFQVRUWC3KGNLJIOREFP5LQ,AGYYVPDD7YG7FYNBX...
# 2  AGU3BBQ2V2DDAMOAKGFAWDDQ6QHA,AESFLDV2PT363T2AQ...
# 3  AEWAZDZZJLQUYVOVGBEUKSLXHQ5A,AG5HTSFRRE6NL3M5S...
# 4  AE3Q6KSUK5P75D5HFYHCRAOLODSA,AFUGIFH5ZAFXRDSZH...
#
#                                            user_name  \
# 0  Manav,Adarsh gupta,Sundeep,S.Sayeed Ahmed,jasp...
# 1  ArdKn,Nirbhay kumar,Sagar Viswanathan,Asp,Plac...
# 2  Kunal,Himanshu,viswanath,sai niharka,saqib mal...
# 3  Omkar dhale,JD,HEMALATHA,Ajwadh a.,amar singh ...
# 4  rahuls6099,Swasat Borah,Ajay Wadke,Pranali,RVK...
#
#                                            review_id  \
# 0  R3HXWT0LRP0NMF,R2AJM3LFTLZHFO,R6AQJGUP6P86,R1K...
# 1  RGIQEG07R9HS2,R1SMWZQ86XIN8U,R2J3Y1WL29GWDE,RY...
# 2  R3J3EQQ9TZI5ZJ,R3E7WBGK7ID0KV,RWU79XKQ6I1QF,R2...
# 3  R3EEUZKKK9J36I,R3HJVYCLYOY554,REDECAZ7AMPQC,R1...
# 4  R1BP4L2HH9TFUP,R16PVJEXKV6QZS,R2UPDB81N66T4P,R...
#
#                                         review_title  \
# 0  Satisfied,Charging is really fast,Value for mo...
# 1  A Good Braided Cable for Your Type C Device,Go...
# 2  Good speed for earlier versions,Good Product,W...
# 3  Good product,Good one,Nice,Really nice product...
# 4  As good as original,Decent,Good one for second...
#
#                                       review_content  \
# 0  Looks durable Charging is fine tooNo complains...
# 1  I ordered this cable to connect my phone to An...
# 2  Not quite durable and sturdy,https://m.media-a...
# 3  Good product,long wire,Charges good,Nice,I bou...
# 4  Bought this instead of original apple, does th...
#
#                                             img_link  \
# 0  https://m.media-amazon.com/images/W/WEBP_40237...
# 1  https://m.media-amazon.com/images/W/WEBP_40237...
# 2  https://m.media-amazon.com/images/W/WEBP_40237...
# 3  https://m.media-amazon.com/images/I/41V5FtEWPk...
# 4  https://m.media-amazon.com/images/W/WEBP_40237...
#
#                                         product_link
# 0  https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...
# 1  https://www.amazon.in/Ambrane-Unbreakable-Char...
# 2  https://www.amazon.in/Sounce-iPhone-Charging-C...
# 3  https://www.amazon.in/Deuce-300-Resistant-Tang...
# 4  https://www.amazon.in/Portronics-Konnect-POR-1...

# %%
amazon_sales.dtypes
# Out:
# product_id             object
# product_name           object
# category               object
# discounted_price       object
# actual_price           object
# discount_percentage    object
# rating                 object
# rating_count           object
# about_product          object
# user_id                object
# user_name              object
# review_id              object
# review_title           object
# review_content         object
# img_link               object
# product_link           object
# dtype: object

# %%
amazon_sales.shape
# Out:
# (1465, 16)

# %%
amazon_sales.columns
# Out:
# Index(['product_id', 'product_name', 'category', 'discounted_price',
#        'actual_price', 'discount_percentage', 'rating', 'rating_count',
#        'about_product', 'user_id', 'user_name', 'review_id', 'review_title',
#        'review_content', 'img_link', 'product_link'],
#       dtype='object')

# %% [markdown]
# The price being used in Indian Rupee

# %%
# Convert the data type of actual_price and discounted_price 
# And replace "₹" and "," so that we can convert it to float

amazon_sales["actual_price"] = amazon_sales["actual_price"].str.replace("₹", "")
amazon_sales["actual_price"] = amazon_sales["actual_price"].str.replace(",", "")
amazon_sales["actual_price"] = amazon_sales["actual_price"].astype("float64")

amazon_sales["discounted_price"] = amazon_sales["discounted_price"].str.replace("₹", "")
amazon_sales["discounted_price"] = amazon_sales["discounted_price"].str.replace(",", "")
amazon_sales["discounted_price"] = amazon_sales["discounted_price"].astype("float64")

# %%
# Convert the data type of discount_percentage and changing the value to get more easy understanding

amazon_sales["discount_percentage"] = (amazon_sales["discount_percentage"]
                                       .str.replace("%", "")
                                       .astype("float64"))

amazon_sales["discount_percentage"] = amazon_sales["discount_percentage"] / 100 
amazon_sales["discount_percentage"]
# Out:
# 0       0.64
# 1       0.43
# 2       0.90
# 3       0.53
# 4       0.61
#         ...
# 1460    0.59
# 1461    0.25
# 1462    0.28
# 1463    0.26
# 1464    0.22
# Name: discount_percentage, Length: 1465, dtype: float64

# %%
#let's checking the rating column if there's unsual string in the column
amazon_sales["rating"].value_counts()
# Out:
# 4.1    244
# 4.3    230
# 4.2    228
# 4.0    129
# 3.9    123
# 4.4    123
# 3.8     86
# 4.5     75
# 4       52
# 3.7     42
# 3.6     35
# 3.5     26
# 4.6     17
# 3.3     16
# 3.4     10
# 4.7      6
# 3.1      4
# 5.0      3
# 3.0      3
# 4.8      3
# 3.2      2
# 2.8      2
# 2.3      1
# |        1
# 2        1
# 3        1
# 2.6      1
# 2.9      1
# Name: rating, dtype: int64

# %%
#get the row of that unsual string 
amazon_sales[amazon_sales["rating"] == "|"]
# Out:
#       product_id                                       product_name  \
# 1279  B08L12N5H1  Eureka Forbes car Vac 100 Watts Powerful Sucti...
#
#                                                category  discounted_price  \
# 1279  Home&Kitchen|Kitchen&HomeAppliances|Vacuum,Cle...            2099.0
#
#       actual_price  discount_percentage rating rating_count  \
# 1279        2499.0                 0.16      |          992
#
#                                           about_product  \
# 1279  No Installation is provided for this product|1...
#
#                                                 user_id  \
# 1279  AGTDSNT2FKVYEPDPXAA673AIS44A,AER2XFSWNN4LAUCJ5...
#
#                                               user_name  \
# 1279  Divya,Dr Nefario,Deekshith,Preeti,Prasanth R,P...
#
#                                               review_id  \
# 1279  R2KKTKM4M9RDVJ,R1O692MZOBTE79,R2WRSEWL56SOS4,R...
#
#                                            review_title  \
# 1279  Decent product,doesn't pick up sand,Ok ok,Must...
#
#                                          review_content  \
# 1279  Does the job well,doesn't work on sand. though...
#
#                                                img_link  \
# 1279  https://m.media-amazon.com/images/W/WEBP_40237...
#
#                                            product_link
# 1279  https://www.amazon.in/Eureka-Forbes-Vacuum-Cle...

# %% [markdown]
# When I look at amazon page of this row, it turns out that this product has 4 stars rating and not |. So I'm planning to give this product rating of 4.0 as well.
#
# Source: https://www.amazon.in/Eureka-Forbes-Vacuum-Cleaner-Washable/dp/B08L12N5H1

# %%
amazon_sales["rating"] = amazon_sales["rating"].str.replace("|", "4.0", regex=False)

amazon_sales["rating"] = amazon_sales["rating"].astype("float64")

# %%
# Checking if the unsual string has changed to 4.0
amazon_sales[amazon_sales["product_id"] == "B08L12N5H1"]
# Out:
#       product_id                                       product_name  \
# 1279  B08L12N5H1  Eureka Forbes car Vac 100 Watts Powerful Sucti...
#
#                                                category  discounted_price  \
# 1279  Home&Kitchen|Kitchen&HomeAppliances|Vacuum,Cle...            2099.0
#
#       actual_price  discount_percentage  rating rating_count  \
# 1279        2499.0                 0.16     4.0          992
#
#                                           about_product  \
# 1279  No Installation is provided for this product|1...
#
#                                                 user_id  \
# 1279  AGTDSNT2FKVYEPDPXAA673AIS44A,AER2XFSWNN4LAUCJ5...
#
#                                               user_name  \
# 1279  Divya,Dr Nefario,Deekshith,Preeti,Prasanth R,P...
#
#                                               review_id  \
# 1279  R2KKTKM4M9RDVJ,R1O692MZOBTE79,R2WRSEWL56SOS4,R...
#
#                                            review_title  \
# 1279  Decent product,doesn't pick up sand,Ok ok,Must...
#
#                                          review_content  \
# 1279  Does the job well,doesn't work on sand. though...
#
#                                                img_link  \
# 1279  https://m.media-amazon.com/images/W/WEBP_40237...
#
#                                            product_link
# 1279  https://www.amazon.in/Eureka-Forbes-Vacuum-Cle...

# %%
# Checking if any missing values

amazon_sales.isnull().sum()
# Out:
# product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 0
# rating_count           2
# about_product          0
# user_id                0
# user_name              0
# review_id              0
# review_title           0
# review_content         0
# img_link               0
# product_link           0
# dtype: int64

# %%
# Checking the those two row that have missing values,
# so we can take look at amazon page to find the missing values 

NaN_data = amazon_sales[amazon_sales.isna().any(axis=1)]
NaN_data
# Out:
#      product_id                                       product_name  \
# 282  B0B94JPY2N  Amazon Brand - Solimo 65W Fast Charging Braide...
# 324  B0BQRJ3C47  REDTECH USB-C to Lightning Cable 3.3FT, [Apple...
#
#                                               category  discounted_price  \
# 282  Computers&Accessories|Accessories&Peripherals|...             199.0
# 324  Computers&Accessories|Accessories&Peripherals|...             249.0
#
#      actual_price  discount_percentage  rating rating_count  \
# 282         999.0                 0.80     3.0          NaN
# 324         999.0                 0.75     5.0          NaN
#
#                                          about_product  \
# 282  USB C to C Cable: This cable has type C connec...
# 324  💎[The Fastest Charge] - This iPhone USB C cabl...
#
#                           user_id    user_name      review_id  \
# 282  AE7CFHY23VAJT2FI4NZKKP6GS2UQ       Pranav   RUB7U91HVZ30
# 324  AGJC5O5H5BBXWUV7WRIEIOOR3TVQ  Abdul Gafur  RQXD5SAMMPC6L
#
#                                      review_title  \
# 282  The cable works but is not 65W as advertised
# 324                               Awesome Product
#
#                                         review_content  \
# 282  I have a pd supported car charger and I bought...
# 324  Quick delivery.Awesome ProductPacking was good...
#
#                                               img_link  \
# 282  https://m.media-amazon.com/images/W/WEBP_40237...
# 324  https://m.media-amazon.com/images/I/31-q0xhaTA...
#
#                                           product_link
# 282  https://www.amazon.in/Amazon-Brand-Charging-Su...
# 324  https://www.amazon.in/REDTECH-Lightning-Certif...

# %% [markdown]
# I checked the first row and found that it has 15 ratings count, so I plan to fill the missing value with 15. However, for the second row, I couldn't access the Amazon page to check the actual value, so I decided to drop the row.
#
# Sources: https://www.amazon.in/Amazon-Brand-Charging-Suitable-Supported/dp/B0B94JPY2N

# %%
#Changing rating_count Column Data Type first 

amazon_sales['rating_count'] = amazon_sales['rating_count'].str.replace(',', '').astype('float64')

# %%
missing_indices = amazon_sales[amazon_sales['rating_count'].isna()].index

# Fill the missing value in the first row with 15

amazon_sales.loc[missing_indices[0], 'rating_count'] = 15.0

# Drop the missing values in the second row

amazon_sales.drop(missing_indices[1], inplace=True)

# %%
# Make sure that the first row has been filled

amazon_sales[amazon_sales["product_id"]== "B0B94JPY2N"]
# Out:
#      product_id                                       product_name  \
# 282  B0B94JPY2N  Amazon Brand - Solimo 65W Fast Charging Braide...
#
#                                               category  discounted_price  \
# 282  Computers&Accessories|Accessories&Peripherals|...             199.0
#
#      actual_price  discount_percentage  rating  rating_count  \
# 282         999.0                  0.8     3.0          15.0
#
#                                          about_product  \
# 282  USB C to C Cable: This cable has type C connec...
#
#                           user_id user_name     review_id  \
# 282  AE7CFHY23VAJT2FI4NZKKP6GS2UQ    Pranav  RUB7U91HVZ30
#
#                                      review_title  \
# 282  The cable works but is not 65W as advertised
#
#                                         review_content  \
# 282  I have a pd supported car charger and I bought...
#
#                                               img_link  \
# 282  https://m.media-amazon.com/images/W/WEBP_40237...
#
#                                           product_link
# 282  https://www.amazon.in/Amazon-Brand-Charging-Su...

# %%
#Checking for Duplicates

amazon_sales.duplicated().sum()
# Out:
# 0

# %%
# Creating a new DataFrame with Selected Column and not including columns that are not necessary for analysis
amazon_sales2 = amazon_sales[['product_id', 'product_name', 'category', 'discounted_price', 
                              'actual_price', 'discount_percentage', 'rating', 'rating_count']].copy()

# %%
# Creating new category columns
category_split = amazon_sales2["category"].str.split("|", expand=True)
category_split
# Out:
#                           0                           1  \
# 0     Computers&Accessories     Accessories&Peripherals
# 1     Computers&Accessories     Accessories&Peripherals
# 2     Computers&Accessories     Accessories&Peripherals
# 3     Computers&Accessories     Accessories&Peripherals
# 4     Computers&Accessories     Accessories&Peripherals
# ...                     ...                         ...
# 1460           Home&Kitchen      Kitchen&HomeAppliances
# 1461           Home&Kitchen      Kitchen&HomeAppliances
# 1462           Home&Kitchen  Heating,Cooling&AirQuality
# 1463           Home&Kitchen  Heating,Cooling&AirQuality
# 1464           Home&Kitchen      Kitchen&HomeAppliances
#
#                                2                         3          4     5  \
# 0             Cables&Accessories                    Cables  USBCables  None
# 1             Cables&Accessories                    Cables  USBCables  None
# 2             Cables&Accessories                    Cables  USBCables  None
# 3             Cables&Accessories                    Cables  USBCables  None
# 4             Cables&Accessories                    Cables  USBCables  None
# ...                          ...                       ...        ...   ...
# 1460  WaterPurifiers&Accessories  WaterPurifierAccessories       None  None
# 1461      SmallKitchenAppliances         Rice&PastaCookers       None  None
# 1462                 RoomHeaters            HeatConvectors       None  None
# 1463                        Fans               ExhaustFans       None  None
# 1464      SmallKitchenAppliances            SandwichMakers       None  None
#
#          6
# 0     None
# 1     None
# 2     None
# 3     None
# 4     None
# ...    ...
# 1460  None
# 1461  None
# 1462  None
# 1463  None
# 1464  None
#
# [1464 rows x 7 columns]

# %%
amazon_sales2["main_category"] = category_split[0]
amazon_sales2["sub_category"] = category_split[1]

# %%
amazon_sales2.drop("category", axis=1, inplace=True)

# %%
amazon_sales2.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#    discounted_price  actual_price  discount_percentage  rating  rating_count  \
# 0             399.0        1099.0                 0.64     4.2       24269.0
# 1             199.0         349.0                 0.43     4.0       43994.0
# 2             199.0        1899.0                 0.90     3.9        7928.0
# 3             329.0         699.0                 0.53     4.2       94363.0
# 4             154.0         399.0                 0.61     4.2       16905.0
#
#            main_category             sub_category
# 0  Computers&Accessories  Accessories&Peripherals
# 1  Computers&Accessories  Accessories&Peripherals
# 2  Computers&Accessories  Accessories&Peripherals
# 3  Computers&Accessories  Accessories&Peripherals
# 4  Computers&Accessories  Accessories&Peripherals

# %%
amazon_sales2["main_category"].value_counts()
# Out:
# Electronics              526
# Computers&Accessories    452
# Home&Kitchen             448
# OfficeProducts            31
# MusicalInstruments         2
# HomeImprovement            2
# Toys&Games                 1
# Car&Motorbike              1
# Health&PersonalCare        1
# Name: main_category, dtype: int64

# %%
# Fixing these strings in the main_category column to look more better
amazon_sales2["main_category"] = amazon_sales2["main_category"].str.replace("&", " & ")
amazon_sales2["main_category"] = amazon_sales2["main_category"].str.replace("HomeImprovement", "Home Improvement")
amazon_sales2["main_category"] = amazon_sales2["main_category"].str.replace("OfficeProducts", "Office Products")
amazon_sales2["main_category"] = amazon_sales2["main_category"].str.replace("MusicalInstruments", "Musical Instruments")

# %%
amazon_sales2["sub_category"].value_counts()
# Out:
# Accessories&Peripherals                    380
# Kitchen&HomeAppliances                     308
# HomeTheater,TV&Video                       162
# Mobiles&Accessories                        161
# Heating,Cooling&AirQuality                 116
# WearableTechnology                          76
# Headphones,Earbuds&Accessories              66
# NetworkingDevices                           34
# OfficePaperProducts                         27
# ExternalDevices&DataStorage                 18
# Cameras&Photography                         16
# HomeStorage&Organization                    16
# HomeAudio                                   16
# GeneralPurposeBatteries&BatteryChargers     14
# Accessories                                 14
# Printers,Inks&Accessories                   11
# CraftMaterials                               7
# Components                                   5
# OfficeElectronics                            4
# Electrical                                   2
# Monitors                                     2
# Microphones                                  2
# Arts&Crafts                                  1
# PowerAccessories                             1
# Tablets                                      1
# Laptops                                      1
# Kitchen&Dining                               1
# CarAccessories                               1
# HomeMedicalSupplies&Equipment                1
# Name: sub_category, dtype: int64

# %%
# Fixing these strings in the sub_category column to look more better

amazon_sales2["sub_category"] = amazon_sales2["sub_category"].str.replace(",", ", ")
amazon_sales2["sub_category"] = amazon_sales2["sub_category"].str.replace("&", " & ")
amazon_sales2["sub_category"] = (amazon_sales2["sub_category"]
                                 .apply(lambda x: re.sub(r'(?<=[a-z])(?=[A-Z])|(?<=\S)(,|&)(?=\S)', " ", x)))

# alternative code
# amazon_sales2["sub_category"] = amazon_sales2["sub_category"].str.replace("WearableTechnology", "Wearable Technology")
# amazon_sales2["sub_category"] = amazon_sales2["sub_category"].str.replace("NetworkingDevices", "Networking Devices")
# amazon_sales2["sub_category"] = amazon_sales2["sub_category"].str.replace("OfficePaperProducts", "Office Paper Products")
# amazon_sales2["sub_category"] = amazon_sales2["sub_category"].str.replace("OfficePaperProducts", "Office Paper Products")

# %%
#creating the differnce price between Actual Price and Discounted Price

amazon_sales2["price_gap"] = amazon_sales2['actual_price'] - amazon_sales2['discounted_price']

# %%
#Creating Categories for Rankings

categories_rating = []
for rating in amazon_sales2["rating"]:
    if rating < 2.0:
        categories_rating.append("Poor")
    elif rating < 3.0:
        categories_rating.append("Below Average")
    elif rating < 4.0:
        categories_rating.append("Average")
    elif rating < 5.0:
        categories_rating.append("Above Average")
    else:
        categories_rating.append("Excellent")

amazon_sales2["rating_category"] = categories_rating
amazon_sales2["rating_category"] = amazon_sales2["rating_category"].astype("category")

# %%
amazon_sales2['rating_category'] = amazon_sales2['rating_category'].cat.reorder_categories(['Below Average', 'Average', 'Above Average', 'Excellent'], ordered=True)

# %%
# Checking a dataframe after all the cleaning and preparation process 

amazon_sales2.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#    discounted_price  actual_price  discount_percentage  rating  rating_count  \
# 0             399.0        1099.0                 0.64     4.2       24269.0
# 1             199.0         349.0                 0.43     4.0       43994.0
# 2             199.0        1899.0                 0.90     3.9        7928.0
# 3             329.0         699.0                 0.53     4.2       94363.0
# 4             154.0         399.0                 0.61     4.2       16905.0
#
#              main_category               sub_category  price_gap  \
# 0  Computers & Accessories  Accessories & Peripherals      700.0
# 1  Computers & Accessories  Accessories & Peripherals      150.0
# 2  Computers & Accessories  Accessories & Peripherals     1700.0
# 3  Computers & Accessories  Accessories & Peripherals      370.0
# 4  Computers & Accessories  Accessories & Peripherals      245.0
#
#   rating_category
# 0   Above Average
# 1   Above Average
# 2         Average
# 3   Above Average
# 4   Above Average

# %%
# Making a new datafram that contain user_id and user_name

amazon_id = amazon_sales[["user_id","user_name"]]
amazon_id.head()
# Out:
#                                              user_id  \
# 0  AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...
# 1  AECPFYFQVRUWC3KGNLJIOREFP5LQ,AGYYVPDD7YG7FYNBX...
# 2  AGU3BBQ2V2DDAMOAKGFAWDDQ6QHA,AESFLDV2PT363T2AQ...
# 3  AEWAZDZZJLQUYVOVGBEUKSLXHQ5A,AG5HTSFRRE6NL3M5S...
# 4  AE3Q6KSUK5P75D5HFYHCRAOLODSA,AFUGIFH5ZAFXRDSZH...
#
#                                            user_name
# 0  Manav,Adarsh gupta,Sundeep,S.Sayeed Ahmed,jasp...
# 1  ArdKn,Nirbhay kumar,Sagar Viswanathan,Asp,Plac...
# 2  Kunal,Himanshu,viswanath,sai niharka,saqib mal...
# 3  Omkar dhale,JD,HEMALATHA,Ajwadh a.,amar singh ...
# 4  rahuls6099,Swasat Borah,Ajay Wadke,Pranali,RVK...

# %%
# Creating user_id to display 1 id for each row

amazon_id_split = amazon_id["user_id"].str.split(",", expand=False)
amazon_id_split = amazon_id_split.explode()
amazon_id_clean = amazon_id_split.reset_index(drop=True)
amazon_id_clean
# Out:
# 0        AG3D6O4STAQKAY2UVGEUV46KN35Q
# 1        AHMY5CWJMMK5BJRBBSNLYT3ONILA
# 2        AHCTC6ULH4XB6YHDY6PCH2R772LQ
# 3        AGYHHIERNXKA6P5T7CZLXKVPT7IQ
# 4        AG4OGOFWXJZTQ2HKYIOCOY3KXF2Q
#                      ...
# 11497    AHXCDNSXAESERITAFELQABFVNLCA
# 11498    AGRZD6CHLCUNOLMMIMIHUCG7PIFA
# 11499    AFQZVGSOSOJHKFQQMCEI4725QEKQ
# 11500    AEALVGXXIP46OZVXKRUXSDWZJMEA
# 11501    AGEFL3AY7YXEFZA4ZJU3LP7K7OJQ
# Name: user_id, Length: 11502, dtype: object

# %%
# Creating user_name to display 1 name for each row

amazon_name = amazon_id["user_name"].str.split(",", expand=False)
amazon_name = amazon_name.explode()
amazon_name_clean = amazon_name.reset_index(drop=True)

amazon_name_clean
# Out:
# 0                   Manav
# 1            Adarsh gupta
# 2                 Sundeep
# 3          S.Sayeed Ahmed
# 4          jaspreet singh
#                ...
# 11509             PARDEEP
# 11510    Anindya Pramanik
# 11511         Vikas Singh
# 11512     Harshada Pimple
# 11513              Saw a.
# Name: user_name, Length: 11514, dtype: object

# %%
# Turn those amazon_id_clean and amazon_name_clean into a datframe

df1 = pd.DataFrame(data=amazon_id_clean)
df2 = pd.DataFrame(data=amazon_name_clean)

# %%
# Merged these 2 DataFrame

amazon_id_name = pd.merge(df1, df2, left_index=True, right_index=True)

# %%
# Checking a new DataFrame for user_id and user_name

amazon_id_name.head()
# Out:
#                         user_id       user_name
# 0  AG3D6O4STAQKAY2UVGEUV46KN35Q           Manav
# 1  AHMY5CWJMMK5BJRBBSNLYT3ONILA    Adarsh gupta
# 2  AHCTC6ULH4XB6YHDY6PCH2R772LQ         Sundeep
# 3  AGYHHIERNXKA6P5T7CZLXKVPT7IQ  S.Sayeed Ahmed
# 4  AG4OGOFWXJZTQ2HKYIOCOY3KXF2Q  jaspreet singh

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## Product Category Analyze

# %% [markdown]
# ### Most Amount of Products by Category

# %%
main_items = (amazon_sales2.groupby('main_category').size()
 .reset_index(name='counts').sort_values("counts", ascending=False).head())
main_items
# Out:
#              main_category  counts
# 2              Electronics     526
# 1  Computers & Accessories     452
# 4           Home & Kitchen     448
# 7          Office Products      31
# 5         Home Improvement       2

# %%
sub_items = (amazon_sales2.groupby('sub_category').size()
 .reset_index(name='counts').sort_values("counts", ascending=False).head())
sub_items
# Out:
#                       sub_category  counts
# 1        Accessories & Peripherals     380
# 17       Kitchen & Home Appliances     308
# 15        Home Theater, TV & Video     162
# 20           Mobiles & Accessories     161
# 11  Heating, Cooling & Air Quality     116

# %%
# Set up figure and axes
fig, ax = plt.subplots(2, 1, figsize=(10, 8))
fig.suptitle('Most Amount of Products by Category', fontsize=16, fontweight='bold')

# Add color
colors = sns.color_palette("pastel", len(main_items))
sns.barplot(ax=ax[0], data=main_items, x='counts', y='main_category', palette=colors)

# Add annotations
for i, v in enumerate(main_items['counts']):
    ax[0].text(v + 50, i, str(v), color='black', fontweight='bold')
ax[0].set_xlabel('Count', fontweight='bold')
ax[0].set_ylabel('Product Main Category', fontweight='bold')
ax[0].set_xlim(right=500)
ax[0].invert_yaxis()

# Add color
colors = sns.color_palette("pastel", len(sub_items))
sns.barplot(ax=ax[1], data=sub_items, x='counts', y='sub_category', palette=colors)

# Add annotations
for i, v in enumerate(sub_items['counts']):
    ax[1].text(v + 50, i, str(v), color='black', fontweight='bold')
ax[1].set_xlabel('Count', fontweight='bold')
ax[1].set_ylabel('Product Sub Category', fontweight='bold')
ax[1].set_xlim(right=400)
ax[1].invert_yaxis()

# Add horizontal lines for easier comparison
for axis in ax:
    axis.grid(True, axis='x', linestyle='--', color='gray', alpha=0.4)
    for i in axis.spines.values():
        i.set_visible(False)
    axis.tick_params(axis='y', which='both', length=0)
    axis.tick_params(axis='x', which='both', length=0)
    axis.axvline(x=axis.get_xlim()[0], color='black', linewidth=1.5, alpha=0.4)
    
plt.tight_layout()
plt.show()

# %% [markdown]
# The electronics category, especially Accessories & Peripherals, covers most of the products in this dataset, and as we can see, this dataset is mainly related to electronic devices

# %% [markdown]
# ## Product Pricing Analyze

# %% [markdown]
# ### What is the average discount percentage for products in each main category and sub category?

# %%
avg_discount_by_category = amazon_sales2.groupby('main_category')[['discount_percentage']].mean()
avg_discount_by_category
# Out:
#                          discount_percentage
# main_category
# Car & Motorbike                     0.420000
# Computers & Accessories             0.539779
# Electronics                         0.508289
# Health & PersonalCare               0.530000
# Home & Kitchen                      0.401205
# Home Improvement                    0.575000
# Musical Instruments                 0.460000
# Office Products                     0.123548
# Toys & Games                        0.000000

# %%
avg_discount_sub_category = amazon_sales2.groupby('sub_category')[['discount_percentage']].mean()
avg_discount_sub_category
# Out:
#                                               discount_percentage
# sub_category
# Accessories                                              0.577857
# Accessories & Peripherals                                0.559289
# Arts & Crafts                                            0.000000
# Cameras & Photography                                    0.475625
# Car Accessories                                          0.420000
# Components                                               0.546000
# Craft Materials                                          0.084286
# Electrical                                               0.575000
# External Devices & Data Storage                          0.468889
# General Purpose Batteries & Battery Chargers             0.167143
# Headphones, Earbuds & Accessories                        0.595303
# Heating, Cooling & Air Quality                           0.406810
# Home Audio                                               0.496875
# Home Medical Supplies & Equipment                        0.530000
# Home Storage & Organization                              0.460625
# Home Theater, TV & Video                                 0.494691
# Kitchen & Dining                                         0.600000
# Kitchen & Home Appliances                                0.402565
# Laptops                                                  0.380000
# Microphones                                              0.460000
# Mobiles & Accessories                                    0.426957
# Monitors                                                 0.505000
# Networking Devices                                       0.477353
# Office Electronics                                       0.012500
# Office Paper Products                                    0.140000
# Power Accessories                                        0.140000
# Printers, Inks & Accessories                             0.215455
# Tablets                                                  0.290000
# Wearable Technology                                      0.698158

# %%
# Calculate the average discount percentage by main category
avg_discount_by_category = amazon_sales2.groupby('main_category')[['discount_percentage']].mean()
avg_discount_by_category *= 100

# Sort the categories by the average discount percentage
avg_discount_by_category = avg_discount_by_category.sort_values('discount_percentage', ascending=False)

# Create a horizontal bar chart
fig, ax = plt.subplots(figsize=(8, 6))
sns.barplot(x='discount_percentage', y=avg_discount_by_category.index, data=avg_discount_by_category, color='skyblue')

# Add labels and a title
ax.set_xlabel('Average discount percentage', fontsize=12, fontweight='bold')
ax.set_ylabel('Main category', fontsize=12, fontweight='bold')
ax.set_title('Average discount percentage by main category', fontsize=14, fontweight='bold')

# Add the percentage values as annotations to the bars
for i, v in enumerate(avg_discount_by_category['discount_percentage']):
    ax.text(v + 0.5, i, str(round(v, 2)) + '%', fontsize=10, fontweight='bold')

# Remove the box around the plot
sns.despine()

plt.show()

# %%
avg_discount_sub_category = amazon_sales2.groupby('sub_category')[['discount_percentage']].mean()
avg_discount_sub_category *= 100

# Sort the categories by the average discount percentage
avg_discount_sub_category = avg_discount_sub_category.sort_values('discount_percentage', ascending=False)

# Create a horizontal bar chart
fig, ax = plt.subplots(figsize=(10, 10))
sns.barplot(x='discount_percentage', y=avg_discount_sub_category.index, data=avg_discount_sub_category, color='skyblue')

# Add labels and a title
ax.set_xlabel('Average discount percentage', fontsize=12, fontweight='bold')
ax.set_ylabel('Sub category', fontsize=12, fontweight='bold')
ax.set_title('Average discount percentage by sub category', fontsize=14, fontweight='bold')

# Add the percentage values as annotations to the bars
for i, v in enumerate(avg_discount_sub_category['discount_percentage']):
    ax.text(v + 0.5, i, str(round(v, 2)) + '%', fontsize=10, fontweight='bold')

# Remove the box around the plot
sns.despine()

plt.show()

# %% [markdown]
# ### 5 Most Discounted Expensive Products

# %%
expensive_product_discounted = amazon_sales2.groupby(["product_name"])[["discounted_price"]].sum().sort_values("discounted_price", ascending=False).reset_index().head()
expensive_product_discounted
# Out:
#                                         product_name  discounted_price
# 0  Sony Bravia 164 cm (65 inches) 4K Ultra HD Sma...           77990.0
# 1  OnePlus 163.8 cm (65 inches) U Series 4K LED S...           61999.0
# 2  VU 164 cm (65 inches) The GloLED Series 4K Sma...           54990.0
# 3  LG 139 cm (55 inches) 4K Ultra HD Smart LED TV...           47990.0
# 4  Samsung 138 cm (55 inches) Crystal 4K Neo Seri...           47990.0

# %%
sns.set_style("whitegrid")
fig, ax = plt.subplots(figsize=(10, 8))
colors = sns.color_palette("pastel", len(expensive_product_discounted))
sns.barplot(x='discounted_price', y='product_name', data=expensive_product_discounted, palette="Set2")

# Add labels and title to the chart
ax.set_xlabel("Discounted Price", fontsize=12, fontweight='bold')
ax.set_ylabel("Product Name", fontsize=12, fontweight='bold')
ax.set_title("Top 5 Most Expensive Products by Discounted Price", fontsize=14, fontweight='bold')

# Add annotations to the chart
for i, v in enumerate(expensive_product_discounted['discounted_price']):
    ax.text(v + 500, i, "${:,.2f}".format(v), color='black', fontweight='bold', fontsize=10)

sns.set_style("white")
sns.despine(left=True, bottom=True)

# Show the plot
plt.show()

# %% [markdown]
# ### 5 Most Discounted Cheapest Product

# %%
cheapest_product_discounted = amazon_sales2.groupby(["product_name"])[["discounted_price"]].sum().sort_values("discounted_price",ascending=True).reset_index().head()
cheapest_product_discounted
# Out:
#                                         product_name  discounted_price
# 0  GIZGA essentials Universal Silicone Keyboard P...             39.00
# 1  Inventis 5V 1.2W Portable Flexible USB LED Lig...             39.00
# 2  E-COSMOS 5V 1.2W Portable Flexible USB LED Lig...             39.00
# 3  Classmate Octane Neon- Blue Gel Pens(Pack of 5...             50.00
# 4  FLiX (Beetel Flow USB to Micro USB PVC Data Sy...             57.89

# %%
sns.set_style("whitegrid")
fig, ax = plt.subplots(figsize=(10, 10))
colors = sns.color_palette("pastel", len(expensive_product_discounted))
sns.barplot(x='discounted_price', y='product_name', data=cheapest_product_discounted, palette="Set2")

ax.set_xlabel("Discounted Price", fontsize=12, fontweight='bold')
ax.set_ylabel("Product Name", fontsize=12, fontweight='bold')
ax.set_title("Top 5 Most Cheapest Products by Discounted Price", fontsize=14, fontweight='bold')

for i, v in enumerate(cheapest_product_discounted['discounted_price']):
    ax.text(v + 0.5, i, "${:,.2f}".format(v), color='black', fontweight='bold', fontsize=10)


    
sns.set_style("white")
sns.despine(left=True, bottom=True)

# Show the plot
plt.show()

# %% [markdown]
# ### Distribution of Actual Price

# %%
sns.set_style('darkgrid')

fig, ax = plt.subplots(figsize=(10, 5))

# create the histogram with a density plot
sns.histplot(data= amazon_sales2, x='actual_price', bins= 20, kde=True, color='green', alpha=0.5)

# add annotations for mean and median ratings

median_rating = amazon_sales2['actual_price'].median()

plt.axvline(median_rating, color='purple', linestyle='--', label='Median Actual Price')
plt.legend()

# set the labels for the plot
ax.set_title('Distribution of Actual Price', fontweight='bold')
ax.set_xlabel('Actual Price', fontweight='bold')
ax.set_ylabel('Count', fontweight='bold')

# change color palette
palette = sns.color_palette('coolwarm')
sns.set_palette(palette)

# display the plot
plt.show()

# %% [markdown]
# ### Distribution of Discounted Price

# %%
sns.set_style('darkgrid')

fig, ax = plt.subplots(figsize=(10, 5))

# create the histogram with a density plot
sns.histplot(data= amazon_sales2, x='discounted_price', bins= 20, kde=True, color='red', alpha=0.5)

# add annotations for mean and median ratings

median_rating = amazon_sales2['discounted_price'].median()

plt.axvline(median_rating, color='white', linestyle='--', label='Median Actual Price')
plt.legend()

# set the labels for the plot
ax.set_title('Distribution of Discounted Price', fontweight='bold')
ax.set_xlabel('Discounted Price', fontweight='bold')
ax.set_ylabel('Count', fontweight='bold')

# change color palette
palette = sns.color_palette('coolwarm')
sns.set_palette(palette)

# display the plot
plt.show()

# %% [markdown]
# ### Exploring the Price Range of Main and Sub Category through Actual and Discounted Prices

# %%
fig, ax = plt.subplots(figsize=(10, 5))
sns.set(style = 'whitegrid')  

sns.stripplot(ax =ax, data = amazon_sales2, y = 'main_category', x= 'actual_price', jitter =0.3)

ax.set_title("Price Range of Main Categories by Actual Price", fontsize=16, fontweight="bold")
ax.set_xlabel("Actual Price", fontsize=12) 
ax.set_ylabel("Main Category", fontsize=12)

sns.despine(left=True)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 5))
sns.set(style = 'whitegrid')  

sns.stripplot(ax =ax, data = amazon_sales2, y = 'main_category', x= 'discounted_price', jitter =0.3)

ax.set_title("Price Range of Main Categories by Discounted Price", fontsize=16, fontweight="bold")
ax.set_xlabel("Discounted Price", fontsize=12)
ax.set_ylabel("Main Category", fontsize=12)

sns.despine(left=True)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 6))
sns.set(style = 'whitegrid')  

sns.stripplot(ax =ax, data = amazon_sales2, y = 'sub_category', x= 'actual_price', jitter =0.3)

ax.set_title("Price Range of Sub Categories by Actual Price", fontsize=16, fontweight="bold")
ax.set_xlabel("Actual Price", fontsize=12)
ax.set_ylabel("Sub Category", fontsize=12)

sns.despine(left=True)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 6))
sns.set(style = 'whitegrid')  

sns.stripplot(ax =ax, data = amazon_sales2, y = 'sub_category', x= 'discounted_price', jitter =0.3)

ax.set_title("Price Range of Sub Categories by Discounted Price", fontsize=16, fontweight="bold")
ax.set_xlabel("Discounted Price", fontsize=12)
ax.set_ylabel("Sub Category", fontsize=12)

sns.despine(left=True)
plt.show()

# %% [markdown]
# ## Product Rating Analysis

# %% [markdown]
# ### Rating and Rating Count Distribution

# %%
# set the style of the plot
sns.set_style('darkgrid')

fig, ax = plt.subplots(figsize=(10, 5))

# create the histogram with a density plot
sns.histplot(data= amazon_sales2, x='rating', bins=15, kde=True, color='purple', alpha=0.5)

# add annotations for mean and median ratings

median_rating = amazon_sales2['rating'].median()

plt.axvline(median_rating, color='green', linestyle='--', label='Median Rating')
plt.legend()

# set the labels for the plot
ax.set_title('Distribution of Ratings for Products')
ax.set_xlabel('Rating')
ax.set_ylabel('Count')

# change color palette
palette = sns.color_palette('coolwarm')
sns.set_palette(palette)

# display the plot
plt.show()

# %%
# set the style of the plot
sns.set_style('darkgrid')

fig, ax = plt.subplots(figsize=(10, 5))

# create the histogram with a density plot
sns.histplot(data= amazon_sales2, x='rating_count', bins=10, kde=True, palette='husl', alpha=0.5)

# add annotations for mean and median ratings

median_rating = amazon_sales2['rating_count'].median()

plt.axvline(median_rating, color='green', linestyle='--', label='Median Rating')
plt.legend()

# set the labels for the plot
ax.set_title('Distribution of Ratings for Products')
ax.set_xlabel('Rating')
ax.set_ylabel('Count')

# change color palette
palette = sns.color_palette('coolwarm')
sns.set_palette(palette)

# display the plot
plt.show()

# %% [markdown]
# ### Rating Percentage of All Products

# %%
rating_category_products = amazon_sales2["rating_category"].value_counts(normalize=True) 
rating_category_products = rating_category_products.rename_axis('rating').reset_index(name='counts')
print(rating_category_products)
# Out:
#           rating    counts
# 0  Above Average  0.756831
# 1        Average  0.237705
# 2  Below Average  0.004098
# 3      Excellent  0.001366

# %%
fig, ax = plt.subplots(figsize=(10, 5))

colors = sns.color_palette("pastel", len(main_items))

rating_category_ordered = ['Below Average', 'Average', 'Above Average', 'Excellent']
rating_count_plot = sns.barplot(data=rating_category_products, x="rating", y="counts", order=rating_category_ordered, palette=colors)
rating_category_products['counts'] = rating_category_products['counts'].round(3)

ax.set_title('Percentage of Products in Each Rating Category',fontweight='bold', fontsize=15)
ax.set_ylabel('Percentage',fontweight='bold', fontsize=12)
ax.set_xlabel('Rating_category',fontweight='bold', fontsize=12)
rating_count_plot.bar_label(rating_count_plot.containers[0])

plt.show()

# %% [markdown]
# Most of the products in this dataset had rated as Above_Average. And No products rated poor in this dataset

# %% [markdown]
# ### Top Main Category by Rating

# %%
top_main_rating = amazon_sales2.groupby(["main_category"])[["rating"]].mean().sort_values("rating",ascending=False).head(10).reset_index()
top_main_rating
# Out:
#              main_category    rating
# 0          Office Products  4.309677
# 1             Toys & Games  4.300000
# 2         Home Improvement  4.250000
# 3  Computers & Accessories  4.153097
# 4              Electronics  4.081749
# 5           Home & Kitchen  4.040625
# 6    Health & PersonalCare  4.000000
# 7      Musical Instruments  3.900000
# 8          Car & Motorbike  3.800000

# %%
sns.set_style('whitegrid')
colors = sns.color_palette("deep", len(main_items))
fig, ax = plt.subplots(figsize=(10, 5))

# create a horizontal bar plot using Seaborn
barplot = sns.barplot(data=top_main_rating, x="main_category", y="rating", palette=colors)
ax.set_xlabel('Main Category',  fontweight='bold', fontsize=10)
ax.set_ylabel('Rating',  fontweight='bold', fontsize=10)
ax.set_title('Top Percentage Main Category by Rating',  fontweight='bold', fontsize=14)

# add annotations to the plot
barplot.bar_label(barplot.containers[0])

plt.xticks(rotation=45)
sns.set_style("white")
sns.despine(left=True, bottom=True)
plt.show()

# %% [markdown]
# ### Top Sub Category by Rating

# %%
top_sub_rating = amazon_sales2.groupby(["sub_category"])[["rating"]].mean().sort_values("rating",ascending=False).head(10).reset_index()
top_sub_rating
# Out:
#                                    sub_category    rating
# 0                                       Tablets  4.600000
# 1                             Power Accessories  4.500000
# 2                            Office Electronics  4.450000
# 3                                    Components  4.380000
# 4  General Purpose Batteries & Battery Chargers  4.350000
# 5                               Craft Materials  4.342857
# 6                                   Accessories  4.335714
# 7               External Devices & Data Storage  4.316667
# 8                                 Arts & Crafts  4.300000
# 9                         Office Paper Products  4.288889

# %%
sns.set_style('whitegrid')
colors = sns.color_palette("deep", len(main_items))
fig, ax = plt.subplots(figsize=(10, 8))

# create a vertical bar plot using Seaborn
sns.barplot(data=top_sub_rating, x="rating", y="sub_category", palette=colors)

ax.set_xlabel('Rating Category',  fontweight='bold', fontsize=10)
ax.set_ylabel('Sub Category',  fontweight='bold', fontsize=10)
ax.set_title('Top Percentage Rating of Sub Category',  fontweight='bold', fontsize=14)

# add annotations to the plot
for i, v in enumerate(top_sub_rating["rating"]):
    ax.text(v + 0.05, i, "{:.1f}%".format(v), color='black', fontweight='bold', fontsize=10)

plt.xticks(rotation=0)
sns.set_style("white")
sns.despine(left=True, bottom=True)
plt.show()

# %% [markdown]
# ## Reviewers Analysis

# %% [markdown]
# ### Most Active Reviewers

# %%
fig, ax = plt.subplots(figsize=(10, 5))
top_reviewer = amazon_id_name['user_name'].value_counts().head(10).rename_axis('username').reset_index(name='counts')

# Create a bar plot with horizontal bars
sns.barplot(data=top_reviewer, x='counts', y='username', palette='viridis_r')
ax.set_xlabel('Amount of Rating Reviews Given', fontweight='bold', fontsize=12)
ax.set_ylabel("Reviewer's Name", fontweight='bold', fontsize=12)
ax.set_title('Top 10 Active Reviewers', fontweight='heavy', size='x-large', y=1.03)

# Add labels for each bar with the reviewer's count
for i, v in enumerate(top_reviewer['counts']):
    ax.text(v + 0.1, i + .15, str(v), color='black', fontweight='bold', fontsize=12)

# Customize the plot's aesthetics
sns.despine()
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# There are more than 600 people who give their reviews of a product and give ratings anonymously under the alias of Amazon Customer, Place Holder, and Kindle Customer.

# %% [markdown]
# ## Observation Correlation

# %% [markdown]
# ### Correlation between Features

# %%
fig, ax = plt.subplots(figsize=(10, 5))
numeric_cols = amazon_sales2.corr()

sns.heatmap(numeric_cols, annot=True)
ax.set_title('Correlation Matrix between Features', fontweight='bold', fontsize=20)


plt.show()

# %% [markdown]
# ### Correlation Scatter Plot between Actual Price and Discounted Price

# %%
fig, ax = plt.subplots(figsize=(10, 5))
sns.set(style = 'whitegrid')  

sns.scatterplot(data=amazon_sales2, x="actual_price", y="discounted_price", color="brown")
ax.set_title('Correlation between Actual Price and Discounted Price',fontweight='bold', fontsize=15)
ax.set_xlabel('Actual Price',fontweight='bold', fontsize=10)
ax.set_ylabel('Discounted Price',fontweight='bold', fontsize=10)
ax.grid(False)

plt.show()

# %% [markdown]
# ## Prediction

# %% [markdown]
# ### Prediction of Discounted Price

# %% [markdown]
# I will try to make a simple linear regression to predict discounted price

# %%
def DistributionPlot(RedFunction, BlueFunction, RedName, BlueName, Title, legend):
    width = 12
    height = 10
    plt.figure(figsize=(width, height))

    ax1 = sns.distplot(RedFunction, hist=False, color="r", label=RedName)
    ax2 = sns.distplot(BlueFunction, hist=False, color="b", label=BlueName, ax=ax1)

    plt.title(Title)
    plt.xlabel('Actual Price (Rupee)')
    plt.ylabel('Discounted Price')
    plt.legend(legend)
    
    plt.show()
    plt.close()

# %%
# I try to make scatterplot for these 4 columns () that i think would be benefical to predict discounted price, then i will look
# at these visualization to decided what feature i will use as predictor 
sns.set_style('darkgrid')

# define features and target variable
X = amazon_sales2[['actual_price', 'rating', 'rating_count', 'price_gap']]
y = amazon_sales2['discounted_price']

# create subplots for each feature
fig, axes = plt.subplots(2, 2, figsize=(13, 8))
sns.regplot(data=amazon_sales2, x="rating", y="discounted_price", ax=axes[0, 0])
sns.regplot(data=amazon_sales2, x="actual_price", y="discounted_price", ax=axes[0, 1])
sns.regplot(data=amazon_sales2, x="rating_count", y="discounted_price", ax=axes[1, 0])
sns.regplot(data=amazon_sales2, x="price_gap", y="discounted_price", ax=axes[1, 1])

# set titles and labels
axes[0, 0].set(title='Discounted Price vs Rating')
axes[0, 1].set(title='Discounted Price vs Actual Price')
axes[1, 0].set(title='Discounted Price vs Rating Count')
axes[1, 1].set(title='Discounted Price vs Price Gap')
plt.tight_layout()
plt.show()

# %% [markdown]
# Based on these four visualizations, it appears that only actual price and discounted price have a strong linear relationship. The other variables do not have a strong relationship with discounted price, except for price gap. However, it is not recommended to include both actual price and price gap as predictor variables in the model since they are highly correlated with each other, and this can lead to multicollinearity issues and overfitting. Therefore, it would be better to choose actual price since it has a higher correlation in the heatmap and a strong linear relationship with discounted price.

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error

# define features and target variable
X = amazon_sales2[['actual_price']]
y = amazon_sales2['discounted_price']

# create a pipeline
pipe = Pipeline([
    ('scaler', StandardScaler()),
    ('regressor', LinearRegression())
])

# split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# fit the pipeline on the training data
pipe.fit(X_train, y_train)

y_pred = pipe.predict(X_test)
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)

print('Coefficients: ', pipe['regressor'].coef_)
print('Intercept: ', pipe['regressor'].intercept_)
# evaluate the pipeline on the testing data
print('R^2 score:', pipe.score(X_test, y_test))

# print results
print('MAE:', mae)
print('MSE:', mse)
# Out:
# Coefficients:  [6680.48379518]
# Intercept:  3120.042032450897
# R^2 score: 0.9518826211553252
# MAE: 776.1054785472894
# MSE: 2252114.7322414923

# %%
plt.figure(figsize=(8,6))
plt.scatter(X_test, y_test)
plt.plot(X_test, y_pred, color='red')
plt.xlabel('Actual Price', fontweight='bold')
plt.ylabel('Discounted Price', fontweight='bold')
plt.title('Plot with Regression Line', fontweight='bold')


plt.show()

# %%
yhat_train = pipe.predict(X_train[['actual_price']])

# %%
Title = 'Distribution  Plot of  Predicted Value Using Training Data vs Training Data Distribution'
DistributionPlot(y_train, yhat_train, "Actual Values (Train)", "Predicted Values (Train)", Title, ['Actual Values (Train)', 'Predicted Values (Train)'])
# Out:
# C:\Users\USER\Documents\anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\USER\Documents\anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
yhat_test = pipe.predict(X_test)

# %%
Title='Distribution  Plot of  Predicted Value Using Test Data vs Data Distribution of Test Data'
DistributionPlot(y_test,yhat_test,"Actual Values (Test)","Predicted Values (Test)",Title, ['Actual Values (Test)', 'Predicted Values (Test)'])
# Out:
# C:\Users\USER\Documents\anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\USER\Documents\anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
from sklearn.model_selection import cross_val_score, KFold

kf = KFold(n_splits=10, shuffle=True, random_state=0)

cv_results = cross_val_score(pipe, X, y, cv=kf)

print('Cross Validation Results Mean: ', cv_results.mean())
# Out:
# Cross Validation Results Mean:  0.9150662659325519

# %% [markdown]
# ## Model Evaluation

# %%
import statsmodels.api as sm
X_sm = sm.add_constant(X)

# Create model, fit, and print results
mod_sm = sm.OLS(y,X_sm)
res_sm = mod_sm.fit()
res_sm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       discounted_price   R-squared:                       0.925
# Model:                            OLS   Adj. R-squared:                  0.925
# Method:                 Least Squares   F-statistic:                 1.810e+04
# Date:                Fri, 12 May 2023   Prob (F-statistic):               0.00
# Time:                        17:52:33   Log-Likelihood:                -13129.
# No. Observations:                1464   AIC:                         2.626e+04
# Df Residuals:                    1462   BIC:                         2.627e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const         -219.1400     55.526     -3.947      0.000    -328.060    -110.220
# actual_price     0.6142      0.005    134.545      0.000       0.605       0.623
# ==============================================================================
# Omnibus:                      520.906   Durbin-Watson:                   1.996
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            62614.020
# Skew:                          -0.599   Prob(JB):                         0.00
# Kurtosis:                      35.016   Cond. No.                     1.36e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.36e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
lm, lm_pvalue, fvalue, f_pvalue = sm.stats.diagnostic.het_white(res_sm.resid, res_sm.model.exog)

print("Lagrange multiplier statistic: " + str(lm))
print("Lagrange multiplier p-value:   " + str(lm_pvalue))
print("F-statistic:                   " + str(fvalue))
print("P-value of F-statistic:        " + str(f_pvalue))

# If the p-value is less than the chosen significance level (e.g. 0.05), 
# reject the null hypothesis of homoscedasticity
if lm_pvalue < 0.05:
    print("Rejected the null hypothesis. Heteroskedasticity detected")
else:
    print("Failed to reject the null hypothesis. No heteroskedasticity detected.")
# Out:
# Lagrange multiplier statistic: 332.861854354688
# Lagrange multiplier p-value:   5.2476723229037627e-73
# F-statistic:                   214.9654182755722
# P-value of F-statistic:        1.4636075729743912e-82
# Rejected the null hypothesis. Heteroskedasticity detected

# %%
# Plot the residuals against the predicted values
sns.set_style('darkgrid')
fig, ax = plt.subplots(figsize=(10, 5))
sns.scatterplot(x=res_sm.fittedvalues, y=res_sm.resid)
ax.set_xlabel('Predicted values')
ax.set_ylabel('Residuals')
ax.set_title('Scatterplot of residuals vs. predicted values')
plt.show()

# %%
residuals = res_sm.resid

plt.figure(figsize=(8,6))
sns.histplot(residuals, kde=True)
plt.show()

# %%
from statsmodels.graphics.gofplots import qqplot

fig, ax = plt.subplots(figsize=(8,6))
qqplot(residuals, line='s', ax=ax)
ax.set_title('QQ Plot of Residuals')
plt.show()

# %% [markdown]
# To check for normal distribution of the error, the data points need to be close to the line. However, in this case, we can observe that there are multiple data points that are significantly distant from the line.

# %%
from scipy.stats import shapiro

# Get the residuals from the fitted model
residuals = res_sm.resid

# Perform Shapiro-Wilk test
stat, p = shapiro(residuals)

# Print the results
print('Shapiro-Wilk test for normality of residuals:')
print('Statistic = %.3f, p-value = %.3f' % (stat, p))

# Interpret the results
if p > 0.05:
    print('The residuals are normally distributed (fail to reject H0)')
else:
    print('The residuals are not normally distributed (reject H0)')
# Out:
# Shapiro-Wilk test for normality of residuals:
# Statistic = 0.607, p-value = 0.000
# The residuals are not normally distributed (reject H0)

# %% [markdown]
# The Shapiro-Wilk test showed that the residuals are not normally distributed with a p-value of 0.000, which means there is strong evidence against the assumption of normality. This assumption is important for linear regression modeling. Since the model may not accurately capture the relationship between the dependent and independent variables, caution should be taken when interpreting the results.

# %% [markdown]
# Based on the analysis, it can be concluded that the Simple Linear Regression Model does not meet the two key assumptions required for a successful linear regression model:
# (1) homoscedasticity
# (2) normally distributed error component.
# The White's test revealed that there is heteroskedasticity in the data, which is also apparent from the scatterplot. In addition, the histograms, quantile plots, and Shapiro-Wilk test indicate that the error component is not normally distributed. Therefore, it is not recommended to use the Simple Linear Regression Model for this dataset.

# %% [markdown]
# # Sentiment Analysis

# %%
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('maxent_ne_chunker')
nltk.download('words')
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %% [markdown]
# I will use Vader model for the sentiment analysis

# %%
amazon_reviews= amazon_sales[["product_id","review_title","review_content"]]

amazon_reviews
# Out:
#       product_id                                       review_title  \
# 0     B07JW9H4J1  Satisfied,Charging is really fast,Value for mo...
# 1     B098NS6PVG  A Good Braided Cable for Your Type C Device,Go...
# 2     B096MSW6CT  Good speed for earlier versions,Good Product,W...
# 3     B08HDJ86NZ  Good product,Good one,Nice,Really nice product...
# 4     B08CF3B7N1  As good as original,Decent,Good one for second...
# ...          ...                                                ...
# 1460  B08L7J3T31  Received the product without spanner,Excellent...
# 1461  B01M6453MB  ok,everything was good couldn't return bcoz I ...
# 1462  B009P2LIL4  very good,Work but front melt after 2 month,Go...
# 1463  B00J5DYCCA  Fan Speed is slow,Good quality,Good product,go...
# 1464  B01486F4G6  Works perfect,Ok good product,Nice Product. Re...
#
#                                          review_content
# 0     Looks durable Charging is fine tooNo complains...
# 1     I ordered this cable to connect my phone to An...
# 2     Not quite durable and sturdy,https://m.media-a...
# 3     Good product,long wire,Charges good,Nice,I bou...
# 4     Bought this instead of original apple, does th...
# ...                                                 ...
# 1460  I received product without spanner,Excellent p...
# 1461  ok,got everything as mentioned but the measuri...
# 1462  plastic but cool body ,u have to find sturdy s...
# 1463  I have installed this in my kitchen working fi...
# 1464  It does it job perfectly..only issue is temp c...
#
# [1464 rows x 3 columns]

# %%
#try to see some texts

example_texts = amazon_reviews["review_title"][100]
example_texts
# Out:
# "Nice cover,Good quality,Dealfreez Full Wrap Silicone Remote Cover Case is an excellent product,Remote Cover,Loved it!,Soft,Best product for the price,Look's good"

# %% [markdown]
# ## Step 1. VADER Sentiment Scoring

# %%
from nltk.sentiment import SentimentIntensityAnalyzer
from tqdm.notebook import tqdm

# %%
sia = SentimentIntensityAnalyzer()

# %%
sia

# %%
#try the result of the example_texts

sia.polarity_scores(example_texts)
# Out:
# {'neg': 0.0, 'neu': 0.637, 'pos': 0.363, 'compound': 0.8655}

# %%
res = {}
for i, row in tqdm(amazon_reviews.iterrows(), total=len(amazon_reviews)):
    text = row["review_content"]
    myid = row["product_id"]
    res[myid] = sia.polarity_scores(text)
# Out:
#   0%|          | 0/1464 [00:00<?, ?it/s]

# %%
res
# Out:
# {'B07JW9H4J1': {'neg': 0.032, 'neu': 0.744, 'pos': 0.224, 'compound': 0.9033},
#  'B098NS6PVG': {'neg': 0.01, 'neu': 0.821, 'pos': 0.169, 'compound': 0.9853},
#  'B096MSW6CT': {'neg': 0.0, 'neu': 0.641, 'pos': 0.359, 'compound': 0.6808},
#  'B08HDJ86NZ': {'neg': 0.028, 'neu': 0.8, 'pos': 0.172, 'compound': 0.8316},
#  'B08CF3B7N1': {'neg': 0.116, 'neu': 0.719, 'pos': 0.165, 'compound': 0.9809},
#  'B08Y1TFSP6': {'neg': 0.087, 'neu': 0.573, 'pos': 0.34, 'compound': 0.6611},
#  'B08WRWPM22': {'neg': 0.028, 'neu': 0.864, 'pos': 0.109, 'compound': 0.8735},
#  'B08DDRGWTJ': {'neg': 0.051, 'neu': 0.801, 'pos': 0.148, 'compound': 0.9334},
#  'B008IFXQFU': {'neg': 0.041, 'neu': 0.828, 'pos': 0.132, 'compound': 0.9956},
#  'B082LZGK39': {'neg': 0.01, 'neu': 0.821, 'pos': 0.169, 'compound': 0.9853},
#  'B08CF3D7QR': {'neg': 0.064, 'neu': 0.797, 'pos': 0.139, 'compound': 0.9236},
#  'B0789LZTCJ': {'neg': 0.028, 'neu': 0.8, 'pos': 0.172, 'compound': 0.8316},
#  'B07KSMBL2H': {'neg': 0.044, 'neu': 0.704, 'pos': 0.253, 'compound': 0.9921},
#  'B085DTN6R2': {'neg': 0.04, 'neu': 0.691, 'pos': 0.269, 'compound': 0.9877},
#  'B09KLVMZ3B': {'neg': 0.025, 'neu': 0.768, 'pos': 0.207, 'compound': 0.9719},
#  'B083342NKJ': {'neg': 0.038, 'neu': 0.658, 'pos': 0.304, 'compound': 0.9698},
#  'B0B6F7LX4C': {'neg': 0.123, 'neu': 0.613, 'pos': 0.264, 'compound': 0.9625},
#  'B082LSVT4B': {'neg': 0.01, 'neu': 0.821, 'pos': 0.169, 'compound': 0.9853},
#  'B08WRBG3XW': {'neg': 0.089, 'neu': 0.834, 'pos': 0.077, 'compound': -0.2724},
#  'B08DPLCM6T': {'neg': 0.108, 'neu': 0.678, 'pos': 0.214, 'compound': 0.875},
#  'B09C6HXFC1': {'neg': 0.0, 'neu': 0.631, 'pos': 0.369, 'compound': 0.9918},
#  'B085194JFL': {'neg': 0.066, 'neu': 0.843, 'pos': 0.09, 'compound': 0.1729},
#  'B09F6S8BT6': {'neg': 0.17, 'neu': 0.745, 'pos': 0.085, 'compound': -0.8476},
#  'B09NHVCHS9': {'neg': 0.0, 'neu': 0.713, 'pos': 0.287, 'compound': 0.9817},
#  'B0B1YVCJ2Y': {'neg': 0.05, 'neu': 0.782, 'pos': 0.168, 'compound': 0.9988},
#  'B01M4GGIVU': {'neg': 0.054, 'neu': 0.782, 'pos': 0.164, 'compound': 0.9816},
#  'B08B42LWKN': {'neg': 0.062, 'neu': 0.78, 'pos': 0.157, 'compound': 0.9966},
#  'B094JNXNPV': {'neg': 0.066, 'neu': 0.833, 'pos': 0.101, 'compound': 0.7626},
#  'B09W5XR9RT': {'neg': 0.0, 'neu': 0.788, 'pos': 0.212, 'compound': 0.9686},
#  'B077Z65HSD': {'neg': 0.013, 'neu': 0.781, 'pos': 0.206, 'compound': 0.9849},
#  'B00NH11PEY': {'neg': 0.019, 'neu': 0.881, 'pos': 0.1, 'compound': 0.9387},
#  'B09CMM3VGK': {'neg': 0.047, 'neu': 0.812, 'pos': 0.141, 'compound': 0.9695},
#  'B08QSC1XY8': {'neg': 0.029, 'neu': 0.742, 'pos': 0.229, 'compound': 0.96},
#  'B008FWZGSG': {'neg': 0.0, 'neu': 0.707, 'pos': 0.293, 'compound': 0.9771},
#  'B0B4HJNPV4': {'neg': 0.023, 'neu': 0.827, 'pos': 0.15, 'compound': 0.836},
#  'B08Y1SJVV5': {'neg': 0.082, 'neu': 0.542, 'pos': 0.376, 'compound': 0.8081},
#  'B07XLCFSSN': {'neg': 0.034, 'neu': 0.695, 'pos': 0.271, 'compound': 0.9934},
#  'B09RZS1NQT': {'neg': 0.049, 'neu': 0.701, 'pos': 0.25, 'compound': 0.9906},
#  'B0B3MMYHYW': {'neg': 0.119, 'neu': 0.784, 'pos': 0.097, 'compound': -0.9821},
#  'B09C6HWG18': {'neg': 0.045, 'neu': 0.754, 'pos': 0.201, 'compound': 0.9839},
#  'B00NH11KIK': {'neg': 0.046, 'neu': 0.852, 'pos': 0.102, 'compound': 0.5499},
#  'B09JPC82QC': {'neg': 0.056, 'neu': 0.78, 'pos': 0.164, 'compound': 0.9998},
#  'B07JW1Y6XV': {'neg': 0.032, 'neu': 0.744, 'pos': 0.224, 'compound': 0.9033},
#  'B07KRCW6LZ': {'neg': 0.049, 'neu': 0.77, 'pos': 0.181, 'compound': 0.969},
#  'B09NJN8L25': {'neg': 0.0, 'neu': 0.713, 'pos': 0.287, 'compound': 0.9817},
#  'B07XJYYH7L': {'neg': 0.046, 'neu': 0.927, 'pos': 0.027, 'compound': -0.1531},
#  'B002PD61Y4': {'neg': 0.049, 'neu': 0.787, 'pos': 0.164, 'compound': 0.8718},
#  'B014I8SSD0': {'neg': 0.044, 'neu': 0.704, 'pos': 0.253, 'compound': 0.9921},
#  'B09L8DSSFH': {'neg': 0.052, 'neu': 0.773, 'pos': 0.174, 'compound': 0.9612},
#  'B07232M876': {'neg': 0.048, 'neu': 0.826, 'pos': 0.127, 'compound': 0.9989},
#  'B07P681N66': {'neg': 0.055, 'neu': 0.848, 'pos': 0.098, 'compound': 0.9846},
#  'B0711PVX6Z': {'neg': 0.048, 'neu': 0.826, 'pos': 0.127, 'compound': 0.9989},
#  'B082T6V3DT': {'neg': 0.015, 'neu': 0.815, 'pos': 0.169, 'compound': 0.9893},
#  'B07MKFNHKG': {'neg': 0.042, 'neu': 0.871, 'pos': 0.087, 'compound': 0.9516},
#  'B0BFWGBX61': {'neg': 0.059, 'neu': 0.71, 'pos': 0.231, 'compound': 0.9562},
#  'B01N90RZ4M': {'neg': 0.05, 'neu': 0.811, 'pos': 0.139, 'compound': 0.5719},
#  'B0088TKTY2': {'neg': 0.041, 'neu': 0.828, 'pos': 0.132, 'compound': 0.9956},
#  'B09Q5SWVBJ': {'neg': 0.062, 'neu': 0.78, 'pos': 0.157, 'compound': 0.9966},
#  'B0B4DT8MKT': {'neg': 0.035, 'neu': 0.78, 'pos': 0.185, 'compound': 0.9651},
#  'B08CDKQ8T6': {'neg': 0.0, 'neu': 0.842, 'pos': 0.158, 'compound': 0.8719},
#  'B07B275VN9': {'neg': 0.022, 'neu': 0.822, 'pos': 0.156, 'compound': 0.8854},
#  'B0B15CPR37': {'neg': 0.047, 'neu': 0.8, 'pos': 0.152, 'compound': 0.9984},
#  'B0994GFWBH': {'neg': 0.063, 'neu': 0.855, 'pos': 0.081, 'compound': 0.1181},
#  'B01GGKZ0V6': {'neg': 0.056, 'neu': 0.78, 'pos': 0.164, 'compound': 0.9291},
#  'B09F9YQQ7B': {'neg': 0.069, 'neu': 0.75, 'pos': 0.181, 'compound': 0.9836},
#  'B014I8SX4Y': {'neg': 0.044, 'neu': 0.704, 'pos': 0.253, 'compound': 0.9921},
#  'B09Q8HMKZX': {'neg': 0.022, 'neu': 0.753, 'pos': 0.225, 'compound': 0.9896},
#  'B0B9XN9S3W': {'neg': 0.033, 'neu': 0.833, 'pos': 0.134, 'compound': 0.9657},
#  'B07966M8XH': {'neg': 0.0, 'neu': 0.774, 'pos': 0.226, 'compound': 0.96},
#  'B01GGKYKQM': {'neg': 0.0, 'neu': 0.793, 'pos': 0.207, 'compound': 0.9815},
#  'B0B86CDHL1': {'neg': 0.051, 'neu': 0.849, 'pos': 0.099, 'compound': 0.9129},
#  'B0B5ZF3NRK': {'neg': 0.016, 'neu': 0.766, 'pos': 0.218, 'compound': 0.9477},
#  'B09RFC46VP': {'neg': 0.069, 'neu': 0.75, 'pos': 0.181, 'compound': 0.9836},
#  'B08R69VDHT': {'neg': 0.035, 'neu': 0.789, 'pos': 0.176, 'compound': 0.9691},
#  'B09RWZRCP1': {'neg': 0.051, 'neu': 0.808, 'pos': 0.14, 'compound': 0.9929},
#  'B09CMP1SC8': {'neg': 0.053, 'neu': 0.735, 'pos': 0.212, 'compound': 0.9924},
#  'B09YLXYP7Y': {'neg': 0.026, 'neu': 0.676, 'pos': 0.298, 'compound': 0.9511},
#  'B09ZPM4C2C': {'neg': 0.02, 'neu': 0.859, 'pos': 0.122, 'compound': 0.886},
#  'B0B2DJDCPX': {'neg': 0.037, 'neu': 0.769, 'pos': 0.194, 'compound': 0.8402},
#  'B0BCZCQTJX': {'neg': 0.083, 'neu': 0.715, 'pos': 0.202, 'compound': 0.9786},
#  'B07LGT55SJ': {'neg': 0.032, 'neu': 0.744, 'pos': 0.224, 'compound': 0.9033},
#  'B09NKZXMWJ': {'neg': 0.0, 'neu': 0.713, 'pos': 0.287, 'compound': 0.9817},
#  'B08QX1CC14': {'neg': 0.07, 'neu': 0.734, 'pos': 0.195, 'compound': 0.9425},
#  'B0974H97TJ': {'neg': 0.0, 'neu': 0.719, 'pos': 0.281, 'compound': 0.9829},
#  'B07GVGTSLN': {'neg': 0.032, 'neu': 0.805, 'pos': 0.163, 'compound': 0.9577},
#  'B09VCHLSJF': {'neg': 0.119, 'neu': 0.784, 'pos': 0.097, 'compound': -0.9821},
#  'B0B1YZX72F': {'neg': 0.05, 'neu': 0.782, 'pos': 0.168, 'compound': 0.9988},
#  'B092BJMT8Q': {'neg': 0.047, 'neu': 0.8, 'pos': 0.152, 'compound': 0.9984},
#  'B0BMXMLSMM': {'neg': 0.044, 'neu': 0.662, 'pos': 0.294, 'compound': 0.9934},
#  'B07JH1C41D': {'neg': 0.032, 'neu': 0.744, 'pos': 0.224, 'compound': 0.9033},
#  'B0141EZMAI': {'neg': 0.024, 'neu': 0.821, 'pos': 0.155, 'compound': 0.9036},
#  'B09Q5P2MT3': {'neg': 0.062, 'neu': 0.78, 'pos': 0.157, 'compound': 0.9966},
#  'B08HDH26JX': {'neg': 0.028, 'neu': 0.8, 'pos': 0.172, 'compound': 0.8316},
#  'B09VT6JKRP': {'neg': 0.0, 'neu': 0.735, 'pos': 0.265, 'compound': 0.9636},
#  'B09T3KB6JZ': {'neg': 0.019, 'neu': 0.88, 'pos': 0.101, 'compound': 0.9879},
#  'B093QCY6YJ': {'neg': 0.0, 'neu': 0.876, 'pos': 0.124, 'compound': 0.7933},
#  'B093ZNQZ2Y': {'neg': 0.048, 'neu': 0.78, 'pos': 0.172, 'compound': 0.9401},
#  'B08LKS3LSP': {'neg': 0.077, 'neu': 0.839, 'pos': 0.084, 'compound': 0.1546},
#  'B00V4BGDKU': {'neg': 0.053, 'neu': 0.791, 'pos': 0.156, 'compound': 0.9919},
#  'B08CHKQ8D4': {'neg': 0.049, 'neu': 0.769, 'pos': 0.183, 'compound': 0.9145},
#  'B09BW334ML': {'neg': 0.057, 'neu': 0.719, 'pos': 0.223, 'compound': 0.8934},
#  'B082T6GVLJ': {'neg': 0.064, 'neu': 0.757, 'pos': 0.18, 'compound': 0.8501},
#  'B07DL1KC3H': {'neg': 0.074, 'neu': 0.801, 'pos': 0.125, 'compound': 0.8014},
#  'B0B6F98KJJ': {'neg': 0.123, 'neu': 0.613, 'pos': 0.264, 'compound': 0.9625},
#  'B07JNVF678': {'neg': 0.044, 'neu': 0.757, 'pos': 0.199, 'compound': 0.9774},
#  'B09QGZFBPM': {'neg': 0.073, 'neu': 0.622, 'pos': 0.305, 'compound': 0.9895},
#  'B07JGDB5M1': {'neg': 0.032, 'neu': 0.744, 'pos': 0.224, 'compound': 0.9033},
#  'B0981XSZJ7': {'neg': 0.035, 'neu': 0.776, 'pos': 0.19, 'compound': 0.9727},
#  'B0B9XLX8VR': {'neg': 0.069, 'neu': 0.758, 'pos': 0.174, 'compound': 0.995},
#  'B08Y5KXR6Z': {'neg': 0.087, 'neu': 0.573, 'pos': 0.34, 'compound': 0.6611},
#  'B09F6VHQXB': {'neg': 0.052, 'neu': 0.694, 'pos': 0.253, 'compound': 0.974},
#  'B0974G5Q2Y': {'neg': 0.013, 'neu': 0.781, 'pos': 0.206, 'compound': 0.9849},
#  'B09YL9SN9B': {'neg': 0.023, 'neu': 0.754, 'pos': 0.223, 'compound': 0.9975},
#  'B09RX1FK54': {'neg': 0.051, 'neu': 0.808, 'pos': 0.14, 'compound': 0.9929},
#  'B09TT6BFDX': {'neg': 0.0, 'neu': 0.739, 'pos': 0.261, 'compound': 0.8727},
#  'B09KH58JZR': {'neg': 0.099, 'neu': 0.833, 'pos': 0.068, 'compound': -0.8288},
#  'B09DDCQFMT': {'neg': 0.06, 'neu': 0.766, 'pos': 0.174, 'compound': 0.8402},
#  'B08RP2L2NL': {'neg': 0.05, 'neu': 0.855, 'pos': 0.094, 'compound': 0.6475},
#  'B0B4G2MWSB': {'neg': 0.063, 'neu': 0.855, 'pos': 0.081, 'compound': 0.1181},
#  'B0B21C4BMX': {'neg': 0.076, 'neu': 0.735, 'pos': 0.189, 'compound': 0.9557},
#  'B084MZXJNK': {'neg': 0.116, 'neu': 0.685, 'pos': 0.199, 'compound': 0.7896},
#  'B0BHZCNC4P': {'neg': 0.0, 'neu': 0.913, 'pos': 0.087, 'compound': 0.6249},
#  'B0B16KD737': {'neg': 0.041, 'neu': 0.795, 'pos': 0.164, 'compound': 0.8984},
#  'B099K9ZX65': {'neg': 0.043, 'neu': 0.767, 'pos': 0.19, 'compound': 0.9986},
#  'B08Y55LPBF': {'neg': 0.069, 'neu': 0.75, 'pos': 0.181, 'compound': 0.9836},
#  'B015OW3M1W': {'neg': 0.028, 'neu': 0.807, 'pos': 0.166, 'compound': 0.9785},
#  'B01D5H8ZI8': {'neg': 0.09, 'neu': 0.811, 'pos': 0.099, 'compound': -0.2621},
#  'B09X1M3DHX': {'neg': 0.035, 'neu': 0.657, 'pos': 0.309, 'compound': 0.9418},
#  'B09MM6P76N': {'neg': 0.032, 'neu': 0.771, 'pos': 0.197, 'compound': 0.9916},
#  'B01D5H8LDM': {'neg': 0.0, 'neu': 0.771, 'pos': 0.229, 'compound': 0.958},
#  'B0B1YY6JJL': {'neg': 0.05, 'neu': 0.782, 'pos': 0.168, 'compound': 0.9988},
#  'B09QGZM8QB': {'neg': 0.073, 'neu': 0.622, 'pos': 0.305, 'compound': 0.9895},
#  'B08L4SBJRY': {'neg': 0.07, 'neu': 0.706, 'pos': 0.224, 'compound': 0.9883},
#  'B09X79PP8F': {'neg': 0.065, 'neu': 0.767, 'pos': 0.168, 'compound': 0.8045},
#  'B082T6GVG9': {'neg': 0.167, 'neu': 0.742, 'pos': 0.091, 'compound': -0.6181},
#  'B0B3XY5YT4': {'neg': 0.108, 'neu': 0.737, 'pos': 0.155, 'compound': 0.934},
#  'B0B4HKH19N': {'neg': 0.023, 'neu': 0.827, 'pos': 0.15, 'compound': 0.836},
#  'B08TGG316Z': {'neg': 0.0, 'neu': 0.851, 'pos': 0.149, 'compound': 0.8583},
#  'B071VMP1Z4': {'neg': 0.089, 'neu': 0.817, 'pos': 0.094, 'compound': -0.3434},
#  'B071SDRGWL': {'neg': 0.013, 'neu': 0.781, 'pos': 0.206, 'compound': 0.9849},
#  'B08PSQRW2T': {'neg': 0.032, 'neu': 0.832, 'pos': 0.136, 'compound': 0.9641},
#  'B0859M539M': {'neg': 0.055, 'neu': 0.848, 'pos': 0.098, 'compound': 0.9846},
#  'B08RX8G496': {'neg': 0.061, 'neu': 0.799, 'pos': 0.14, 'compound': 0.9422},
#  'B002SZEOLG': {'neg': 0.041, 'neu': 0.828, 'pos': 0.132, 'compound': 0.9956},
#  'B08CS3BT4L': {'neg': 0.07, 'neu': 0.804, 'pos': 0.125, 'compound': 0.9886},
#  'B00RFWNJMC': {'neg': 0.117, 'neu': 0.79, 'pos': 0.093, 'compound': -0.3071},
#  'B082T6GXS5': {'neg': 0.07, 'neu': 0.691, 'pos': 0.238, 'compound': 0.9788},
#  'B09CMQRQM6': {'neg': 0.033, 'neu': 0.748, 'pos': 0.22, 'compound': 0.9951},
#  'B005LJQMCK': {'neg': 0.063, 'neu': 0.755, 'pos': 0.182, 'compound': 0.9457},
#  'B09C6H53KH': {'neg': 0.055, 'neu': 0.796, 'pos': 0.149, 'compound': 0.9743},
#  'B0BB3CBFBM': {'neg': 0.065, 'neu': 0.755, 'pos': 0.18, 'compound': 0.9913},
#  'B08QSDKFGQ': {'neg': 0.029, 'neu': 0.742, 'pos': 0.229, 'compound': 0.96},
#  'B08PV1X771': {'neg': 0.17, 'neu': 0.745, 'pos': 0.085, 'compound': -0.8476},
#  'B07YTNKVJQ': {'neg': 0.051, 'neu': 0.801, 'pos': 0.148, 'compound': 0.9334},
#  'B0117H7GZ6': {'neg': 0.043, 'neu': 0.87, 'pos': 0.087, 'compound': 0.9778},
#  'B09XJ1LM7R': {'neg': 0.413, 'neu': 0.587, 'pos': 0.0, 'compound': -0.7926},
#  'B084N133Y7': {'neg': 0.116, 'neu': 0.685, 'pos': 0.199, 'compound': 0.7896},
#  'B088Z1YWBC': {'neg': 0.027, 'neu': 0.793, 'pos': 0.179, 'compound': 0.9998},
#  'B07VSG5SXZ': {'neg': 0.054, 'neu': 0.824, 'pos': 0.122, 'compound': 0.8115},
#  'B08RWCZ6SY': {'neg': 0.098, 'neu': 0.779, 'pos': 0.123, 'compound': 0.3821},
#  'B07KSB1MLX': {'neg': 0.035, 'neu': 0.837, 'pos': 0.128, 'compound': 0.9745},
#  'B081FG1QYX': {'neg': 0.058, 'neu': 0.839, 'pos': 0.102, 'compound': 0.9448},
#  'B08R69WBN7': {'neg': 0.035, 'neu': 0.789, 'pos': 0.176, 'compound': 0.9691},
#  'B0B3RHX6B6': {'neg': 0.035, 'neu': 0.664, 'pos': 0.301, 'compound': 0.9246},
#  'B084N18QZY': {'neg': 0.043, 'neu': 0.747, 'pos': 0.211, 'compound': 0.9892},
#  'B081NHWT6Z': {'neg': 0.03, 'neu': 0.71, 'pos': 0.26, 'compound': 0.9826},
#  'B07JPJJZ2H': {'neg': 0.044, 'neu': 0.757, 'pos': 0.199, 'compound': 0.9774},
#  'B09JKNF147': {'neg': 0.0, 'neu': 0.807, 'pos': 0.193, 'compound': 0.9039},
#  'B0B9959XF3': {'neg': 0.084, 'neu': 0.656, 'pos': 0.26, 'compound': 0.9985},
#  'B09PNR6F8Q': {'neg': 0.019, 'neu': 0.799, 'pos': 0.182, 'compound': 0.9108},
#  'B07M69276N': {'neg': 0.016, 'neu': 0.832, 'pos': 0.152, 'compound': 0.9893},
#  'B0B1YZ9CB8': {'neg': 0.05, 'neu': 0.782, 'pos': 0.168, 'compound': 0.9988},
#  'B09YLYB9PB': {'neg': 0.026, 'neu': 0.676, 'pos': 0.298, 'compound': 0.9511},
#  'B08CTNJ985': {'neg': 0.052, 'neu': 0.82, 'pos': 0.128, 'compound': 0.9446},
#  'B0BP7XLX48': {'neg': 0.0, 'neu': 0.588, 'pos': 0.412, 'compound': 0.9382},
#  'B09LHXNZLR': {'neg': 0.0, 'neu': 0.774, 'pos': 0.226, 'compound': 0.9552},
#  'B0B3N8VG24': {'neg': 0.0, 'neu': 0.713, 'pos': 0.287, 'compound': 0.9817},
#  'B08PSVBB2X': {'neg': 0.032, 'neu': 0.832, 'pos': 0.136, 'compound': 0.9641},
#  'B0B3MQXNFB': {'neg': 0.0, 'neu': 0.713, 'pos': 0.287, 'compound': 0.9817},
#  'B08XMSKKMM': {'neg': 0.109, 'neu': 0.784, 'pos': 0.107, 'compound': 0.2981},
#  'B09L8DT7D6': {'neg': 0.024, 'neu': 0.614, 'pos': 0.362, 'compound': 0.948},
#  'B00GE55L22': {'neg': 0.0, 'neu': 0.839, 'pos': 0.161, 'compound': 0.9344},
#  'B0162K34H2': {'neg': 0.085, 'neu': 0.748, 'pos': 0.167, 'compound': 0.8725},
#  'B0B8SRZ5SV': {'neg': 0.034, 'neu': 0.695, 'pos': 0.271, 'compound': 0.9934},
#  'B07CWNJLPC': {'neg': 0.035, 'neu': 0.868, 'pos': 0.097, 'compound': 0.8316},
#  'B00NH12R1O': {'neg': 0.0, 'neu': 0.635, 'pos': 0.365, 'compound': 0.9825},
#  'B0B8SSC5D9': {'neg': 0.034, 'neu': 0.695, 'pos': 0.271, 'compound': 0.9934},
#  'B08WKG2MWT': {'neg': 0.073, 'neu': 0.622, 'pos': 0.305, 'compound': 0.9895},
#  'B0B466C3G4': {'neg': 0.024, 'neu': 0.853, 'pos': 0.123, 'compound': 0.9606},
#  'B005LJQMZC': {'neg': 0.063, 'neu': 0.755, 'pos': 0.182, 'compound': 0.9457},
#  'B07MDRGHWQ': {'neg': 0.042, 'neu': 0.871, 'pos': 0.087, 'compound': 0.9516},
#  'B07DC4RZPY': {'neg': 0.0, 'neu': 0.833, 'pos': 0.167, 'compound': 0.7791},
#  'B0B15GSPQW': {'neg': 0.047, 'neu': 0.8, 'pos': 0.152, 'compound': 0.9984},
#  'B08GJNM9N7': {'neg': 0.028, 'neu': 0.656, 'pos': 0.316, 'compound': 0.9554},
#  'B09C6FML9B': {'neg': 0.131, 'neu': 0.764, 'pos': 0.105, 'compound': -0.6026},
#  'B0B65MJ45G': {'neg': 0.026, 'neu': 0.88, 'pos': 0.094, 'compound': 0.6486},
#  'B08P9RYPLR': {'neg': 0.0, 'neu': 0.713, 'pos': 0.287, 'compound': 0.9817},
#  'B0B6F8HHR6': {'neg': 0.123, 'neu': 0.613, 'pos': 0.264, 'compound': 0.9625},
#  'B084MZXJN6': {'neg': 0.0, 'neu': 0.892, 'pos': 0.108, 'compound': 0.899},
#  'B08XMG618K': {'neg': 0.0, 'neu': 0.79, 'pos': 0.21, 'compound': 0.7935},
#  'B0BCKWZ884': {'neg': 0.01, 'neu': 0.619, 'pos': 0.371, 'compound': 0.9905},
#  'B00GGGOYEK': {'neg': 0.0, 'neu': 0.695, 'pos': 0.305, 'compound': 0.9684},
#  'B07ZR4S1G4': {'neg': 0.163, 'neu': 0.682, 'pos': 0.155, 'compound': -0.0179},
#  'B09C635BMM': {'neg': 0.095, 'neu': 0.689, 'pos': 0.216, 'compound': 0.9869},
#  'B00GG59HU2': {'neg': 0.0, 'neu': 0.685, 'pos': 0.315, 'compound': 0.8885},
#  'B00RGLI0ZS': {'neg': 0.051, 'neu': 0.719, 'pos': 0.23, 'compound': 0.9939},
#  'B09ZPJT8B2': {'neg': 0.0, 'neu': 0.665, 'pos': 0.335, 'compound': 0.891},
#  'B07HZ2QCGR': {'neg': 0.075, 'neu': 0.837, 'pos': 0.088, 'compound': 0.9206},
#  'B095244Q22': {'neg': 0.032, 'neu': 0.749, 'pos': 0.219, 'compound': 0.9755},
#  'B08CKW1KH9': {'neg': 0.092, 'neu': 0.655, 'pos': 0.253, 'compound': 0.9421},
#  'B0BLV1GNLN': {'neg': 0.08, 'neu': 0.672, 'pos': 0.248, 'compound': 0.9781},
#  'B08RHPDNVV': {'neg': 0.076, 'neu': 0.817, 'pos': 0.106, 'compound': 0.3376},
#  'B00NH13Q8W': {'neg': 0.019, 'neu': 0.881, 'pos': 0.1, 'compound': 0.9387},
#  'B0B8SSZ76F': {'neg': 0.061, 'neu': 0.825, 'pos': 0.114, 'compound': 0.9275},
#  'B0841KQR1Z': {'neg': 0.068, 'neu': 0.795, 'pos': 0.137, 'compound': 0.6486},
#  'B0B467CCB9': {'neg': 0.0, 'neu': 0.833, 'pos': 0.167, 'compound': 0.5574},
#  'B095JQVC7N': {'neg': 0.063, 'neu': 0.856, 'pos': 0.081, 'compound': 0.849},
#  'B08PPHFXG3': {'neg': 0.096, 'neu': 0.746, 'pos': 0.159, 'compound': 0.5106},
#  'B06XR9PR5X': {'neg': 0.041, 'neu': 0.651, 'pos': 0.308, 'compound': 0.9388},
#  'B09JSW16QD': {'neg': 0.106, 'neu': 0.756, 'pos': 0.138, 'compound': 0.7644},
#  'B07JH1CBGW': {'neg': 0.032, 'neu': 0.744, 'pos': 0.224, 'compound': 0.9033},
#  'B09127FZCK': {'neg': 0.068, 'neu': 0.779, 'pos': 0.152, 'compound': 0.8334},
#  'B083GQGT3Z': {'neg': 0.125, 'neu': 0.753, 'pos': 0.121, 'compound': -0.0161},
#  'B09Q8WQ5QJ': {'neg': 0.026, 'neu': 0.823, 'pos': 0.151, 'compound': 0.9932},
#  'B07YZG8PPY': {'neg': 0.042, 'neu': 0.818, 'pos': 0.14, 'compound': 0.9801},
#  'B09H39KTTB': {'neg': 0.101, 'neu': 0.755, 'pos': 0.144, 'compound': 0.362},
#  'B08DCVRW98': {'neg': 0.022, 'neu': 0.844, 'pos': 0.133, 'compound': 0.9072},
#  'B0718ZN31Q': {'neg': 0.081, 'neu': 0.66, 'pos': 0.259, 'compound': 0.9216},
#  'B0162LYSFS': {'neg': 0.0, 'neu': 0.87, 'pos': 0.13, 'compound': 0.4588},
#  'B07PFJ5VQD': {'neg': 0.051, 'neu': 0.77, 'pos': 0.178, 'compound': 0.8852},
#  'B01J8S6X2I': {'neg': 0.031, 'neu': 0.825, 'pos': 0.144, 'compound': 0.9886},
#  'B09MJ77786': {'neg': 0.091, 'neu': 0.645, 'pos': 0.263, 'compound': 0.9936},
#  'B09NNGHG22': {'neg': 0.01, 'neu': 0.864, 'pos': 0.125, 'compound': 0.9604},
#  'B07V5YF4ND': {'neg': 0.0, 'neu': 0.879, 'pos': 0.121, 'compound': 0.7003},
#  'B0B65P827P': {'neg': 0.026, 'neu': 0.88, 'pos': 0.094, 'compound': 0.6486},
#  'B084MZYBTV': {'neg': 0.014, 'neu': 0.782, 'pos': 0.204, 'compound': 0.9763},
#  'B097ZQTDVZ': {'neg': 0.067, 'neu': 0.843, 'pos': 0.091, 'compound': 0.558},
#  'B0B5F3YZY4': {'neg': 0.05, 'neu': 0.708, 'pos': 0.242, 'compound': 0.9967},
#  'B09G5TSGXV': {'neg': 0.086, 'neu': 0.747, 'pos': 0.167, 'compound': 0.8905},
#  'B006LW0WDQ': {'neg': 0.065, 'neu': 0.817, 'pos': 0.118, 'compound': 0.9734},
#  'B09YLX91QR': {'neg': 0.026, 'neu': 0.676, 'pos': 0.298, 'compound': 0.9511},
#  'B081FJWN52': {'neg': 0.058, 'neu': 0.839, 'pos': 0.102, 'compound': 0.9448},
#  'B0758F7KK7': {'neg': 0.094, 'neu': 0.756, 'pos': 0.15, 'compound': 0.913},
#  'B09L835C3V': {'neg': 0.037, 'neu': 0.85, 'pos': 0.113, 'compound': 0.7962},
#  'B098TV3L96': {'neg': 0.055, 'neu': 0.801, 'pos': 0.144, 'compound': 0.8883},
#  'B08NCKT9FG': {'neg': 0.0, 'neu': 0.719, 'pos': 0.281, 'compound': 0.9829},
#  'B0B4T6MR8N': {'neg': 0.023, 'neu': 0.827, 'pos': 0.15, 'compound': 0.836},
#  'B01GGKZ4NU': {'neg': 0.056, 'neu': 0.78, 'pos': 0.164, 'compound': 0.9291},
#  'B09BW2GP18': {'neg': 0.056, 'neu': 0.745, 'pos': 0.199, 'compound': 0.9393},
#  'B09WN3SRC7': {'neg': 0.043, 'neu': 0.778, 'pos': 0.179, 'compound': 0.9985},
#  'B09B125CFJ': {'neg': 0.016, 'neu': 0.795, 'pos': 0.188, 'compound': 0.984},
#  'B09RQRZW2X': {'neg': 0.124, 'neu': 0.79, 'pos': 0.085, 'compound': -0.3352},
#  'B07924P3C5': {'neg': 0.054, 'neu': 0.811, 'pos': 0.135, 'compound': 0.9442},
#  'B08N1WL9XW': {'neg': 0.0, 'neu': 0.713, 'pos': 0.287, 'compound': 0.9817},
#  'B07VVXJ2P5': {'neg': 0.11, 'neu': 0.801, 'pos': 0.089, 'compound': -0.4109},
#  'B0BC8BQ432': {'neg': 0.069, 'neu': 0.758, 'pos': 0.174, 'compound': 0.995},
#  'B06XFTHCNY': {'neg': 0.03, 'neu': 0.74, 'pos': 0.23, 'compound': 0.9779},
#  'B08CT62BM1': {'neg': 0.052, 'neu': 0.82, 'pos': 0.128, 'compound': 0.9446},
#  'B07CRL2GY6': {'neg': 0.028, 'neu': 0.8, 'pos': 0.172, 'compound': 0.8316},
#  'B07DWFX9YS': {'neg': 0.028, 'neu': 0.848, 'pos': 0.123, 'compound': 0.9154},
#  'B01D5H90L4': {'neg': 0.046, 'neu': 0.751, 'pos': 0.203, 'compound': 0.9926},
#  'B07F1P8KNV': {'neg': 0.032, 'neu': 0.805, 'pos': 0.163, 'compound': 0.9577},
#  'B084N1BM9L': {'neg': 0.0, 'neu': 0.892, 'pos': 0.108, 'compound': 0.899},
#  'B09F6D21BY': {'neg': 0.12, 'neu': 0.796, 'pos': 0.084, 'compound': -0.5267},
#  'B09LQQYNZQ': {'neg': 0.158, 'neu': 0.752, 'pos': 0.09, 'compound': -0.9808},
#  'B0BC9BW512': {'neg': 0.05, 'neu': 0.782, 'pos': 0.168, 'compound': 0.9988},
#  'B0B61HYR92': {'neg': 0.145, 'neu': 0.777, 'pos': 0.079, 'compound': -0.4525},
#  'B075ZTJ9XR': {'neg': 0.0, 'neu': 0.849, 'pos': 0.151, 'compound': 0.9097},
#  'B0978V2CP6': {'neg': 0.067, 'neu': 0.86, 'pos': 0.073, 'compound': 0.4988},
#  'B09LRZYBH1': {'neg': 0.082, 'neu': 0.727, 'pos': 0.191, 'compound': 0.9125},
#  'B0B997FBZT': {'neg': 0.084, 'neu': 0.656, 'pos': 0.26, 'compound': 0.9985},
#  'B098LCVYPW': {'neg': 0.049, 'neu': 0.753, 'pos': 0.198, 'compound': 0.8874},
#  'B09HV71RL1': {'neg': 0.049, 'neu': 0.769, 'pos': 0.183, 'compound': 0.9145},
#  'B08PZ6HZLT': {'neg': 0.0, 'neu': 0.603, 'pos': 0.397, 'compound': 0.9643},
#  'B075TJHWVC': {'neg': 0.152, 'neu': 0.665, 'pos': 0.184, 'compound': 0.2732},
#  'B09LV13JFB': {'neg': 0.149, 'neu': 0.819, 'pos': 0.033, 'compound': -0.7479},
#  'B092BL5DCX': {'neg': 0.047, 'neu': 0.8, 'pos': 0.152, 'compound': 0.9984},
#  'B09VH568H7': {'neg': 0.049, 'neu': 0.821, 'pos': 0.131, 'compound': 0.4939},
#  'B09HQSV46W': {'neg': 0.123, 'neu': 0.613, 'pos': 0.264, 'compound': 0.9625},
#  'B08TZD7FQN': {'neg': 0.047, 'neu': 0.776, 'pos': 0.177, 'compound': 0.8874},
#  'B0B21XL94T': {'neg': 0.061, 'neu': 0.781, 'pos': 0.158, 'compound': 0.9432},
#  'B09PTT8DZF': {'neg': 0.075, 'neu': 0.773, 'pos': 0.152, 'compound': 0.6486},
#  'B0B94JPY2N': {'neg': 0.028, 'neu': 0.853, 'pos': 0.119, 'compound': 0.743},
#  'B0B3XXSB1K': {'neg': 0.108, 'neu': 0.737, 'pos': 0.155, 'compound': 0.934},
#  'B08RZ12GKR': {'neg': 0.046, 'neu': 0.782, 'pos': 0.172, 'compound': 0.8922},
#  'B0B4T8RSJ1': {'neg': 0.023, 'neu': 0.827, 'pos': 0.15, 'compound': 0.836},
#  'B0B7B9V9QP': {'neg': 0.05, 'neu': 0.726, 'pos': 0.225, 'compound': 0.9849},
#  'B08XXVXP3J': {'neg': 0.119, 'neu': 0.79, 'pos': 0.091, 'compound': -0.6542},
#  'B06XGWRKYT': {'neg': 0.101, 'neu': 0.806, 'pos': 0.093, 'compound': -0.5404},
#  'B07CWDX49D': {'neg': 0.035, 'neu': 0.868, 'pos': 0.097, 'compound': 0.8316},
#  'B09TY4MSH3': {'neg': 0.052, 'neu': 0.822, 'pos': 0.126, 'compound': 0.9107},
#  'B07RY2X9MP': {'neg': 0.0, 'neu': 0.749, 'pos': 0.251, 'compound': 0.98},
#  'B0B2C5MJN6': {'neg': 0.029, 'neu': 0.765, 'pos': 0.206, 'compound': 0.9803},
#  'B0BBMGLQDW': {'neg': 0.0, 'neu': 0.747, 'pos': 0.253, 'compound': 0.8591},
#  'B01LONQBDG': {'neg': 0.021, 'neu': 0.844, 'pos': 0.134, 'compound': 0.9867},
#  'B08XXF5V6G': {'neg': 0.039, 'neu': 0.74, 'pos': 0.221, 'compound': 0.9292},
#  'B09HK9JH4F': {'neg': 0.037, 'neu': 0.85, 'pos': 0.113, 'compound': 0.7962},
#  'B09MMD1FDN': {'neg': 0.051, 'neu': 0.757, 'pos': 0.192, 'compound': 0.9611},
#  'B09HN7LD5L': {'neg': 0.0, 'neu': 0.786, 'pos': 0.214, 'compound': 0.9719},
#  'B0BNDD9TN6': {'neg': 0.0, 'neu': 0.822, 'pos': 0.178, 'compound': 0.8436},
#  'B0941392C8': {'neg': 0.042, 'neu': 0.911, 'pos': 0.047, 'compound': 0.1007},
#  'B01M5967SY': {'neg': 0.054, 'neu': 0.782, 'pos': 0.164, 'compound': 0.9816},
#  'B016MDK4F4': {'neg': 0.0, 'neu': 0.575, 'pos': 0.425, 'compound': 0.8126},
#  'B08G43CCLC': {'neg': 0.072, 'neu': 0.745, 'pos': 0.183, 'compound': 0.8094},
#  'B0B61GCHC1': {'neg': 0.049, 'neu': 0.676, 'pos': 0.275, 'compound': 0.9495},
#  'B07RX14W1Q': {'neg': 0.053, 'neu': 0.791, 'pos': 0.156, 'compound': 0.8952},
#  'B09PLD9TCD': {'neg': 0.0, 'neu': 0.762, 'pos': 0.238, 'compound': 0.9175},
#  'B0B8ZKWGKD': {'neg': 0.046, 'neu': 0.647, 'pos': 0.307, 'compound': 0.958},
#  'B09NNJ9WYM': {'neg': 0.108, 'neu': 0.662, 'pos': 0.23, 'compound': 0.9794},
#  'B08H5L8V1L': {'neg': 0.057, 'neu': 0.759, 'pos': 0.185, 'compound': 0.9617},
#  'B0B8CXTTG3': {'neg': 0.123, 'neu': 0.613, 'pos': 0.264, 'compound': 0.9625},
#  'B09HCH3JZG': {'neg': 0.011, 'neu': 0.892, 'pos': 0.097, 'compound': 0.9594},
#  'B097JVLW3L': {'neg': 0.062, 'neu': 0.767, 'pos': 0.171, 'compound': 0.9547},
#  'B09SB6SJB4': {'neg': 0.028, 'neu': 0.766, 'pos': 0.206, 'compound': 0.9674},
#  'B08NW8GHCJ': {'neg': 0.0, 'neu': 0.83, 'pos': 0.17, 'compound': 0.9456},
#  'B09YHLPQYT': {'neg': 0.02, 'neu': 0.759, 'pos': 0.22, 'compound': 0.9797},
#  'B08G1RW2Q3': {'neg': 0.0, 'neu': 0.814, 'pos': 0.186, 'compound': 0.964},
#  'B08YXJJW8H': {'neg': 0.037, 'neu': 0.682, 'pos': 0.28, 'compound': 0.9891},
#  'B09P8M18QM': {'neg': 0.067, 'neu': 0.815, 'pos': 0.117, 'compound': 0.273},
#  'B08BG4M4N7': {'neg': 0.032, 'neu': 0.7, 'pos': 0.268, 'compound': 0.9531},
#  'B07VJ9ZTXS': {'neg': 0.016, 'neu': 0.777, 'pos': 0.207, 'compound': 0.9951},
#  'B084872DQY': {'neg': 0.063, 'neu': 0.81, 'pos': 0.127, 'compound': 0.9955},
#  'B00GGGOYEU': {'neg': 0.101, 'neu': 0.75, 'pos': 0.149, 'compound': 0.7389},
#  'B08FD2VSD9': {'neg': 0.0, 'neu': 0.923, 'pos': 0.077, 'compound': 0.3818},
#  'B095JPKPH3': {'neg': 0.063, 'neu': 0.856, 'pos': 0.081, 'compound': 0.849},
#  'B087JWLZ2K': {'neg': 0.049, 'neu': 0.8, 'pos': 0.151, 'compound': 0.9921},
#  'B09DSXK8JX': {'neg': 0.0, 'neu': 0.762, 'pos': 0.238, 'compound': 0.9175},
#  'B08V9C4B1J': {'neg': 0.0, 'neu': 0.83, 'pos': 0.17, 'compound': 0.9456},
#  'B08PKBMJKS': {'neg': 0.021, 'neu': 0.878, 'pos': 0.101, 'compound': 0.9118},
#  'B0B8VQ7KDS': {'neg': 0.066, 'neu': 0.728, 'pos': 0.206, 'compound': 0.7003},
#  'B086JTMRYL': {'neg': 0.0, 'neu': 0.789, 'pos': 0.211, 'compound': 0.9169},
#  'B09RWQ7YR6': {'neg': 0.093, 'neu': 0.638, 'pos': 0.269, 'compound': 0.9936},
#  'B00OFM6PEO': {'neg': 0.0, 'neu': 0.644, 'pos': 0.356, 'compound': 0.9141},
#  'B0BF57RN3K': {'neg': 0.05, 'neu': 0.802, 'pos': 0.148, 'compound': 0.9952},
#  'B0B3RRWSF6': {'neg': 0.035, 'neu': 0.751, 'pos': 0.214, 'compound': 0.9995},
#  'B0B5B6PQCT': {'neg': 0.04, 'neu': 0.725, 'pos': 0.235, 'compound': 0.999},
#  'B08HV83HL3': {'neg': 0.009, 'neu': 0.858, 'pos': 0.133, 'compound': 0.9883},
#  'B0BBN4DZBD': {'neg': 0.035, 'neu': 0.788, 'pos': 0.177, 'compound': 0.9849},
#  'B0B3CPQ5PF': {'neg': 0.08, 'neu': 0.775, 'pos': 0.145, 'compound': 0.997},
#  'B0B3CQBRB4': {'neg': 0.08, 'neu': 0.775, 'pos': 0.145, 'compound': 0.997},
#  'B0BBN56J5H': {'neg': 0.035, 'neu': 0.788, 'pos': 0.177, 'compound': 0.9849},
#  'B0BBN3WF7V': {'neg': 0.035, 'neu': 0.788, 'pos': 0.177, 'compound': 0.9849},
#  'B0BDRVFDKP': {'neg': 0.02, 'neu': 0.841, 'pos': 0.139, 'compound': 0.85},
#  'B0B5LVS732': {'neg': 0.056, 'neu': 0.727, 'pos': 0.217, 'compound': 0.9953},
#  'B09V2Q4QVQ': {'neg': 0.06, 'neu': 0.701, 'pos': 0.239, 'compound': 0.9897},
#  'B09V12K8NT': {'neg': 0.039, 'neu': 0.676, 'pos': 0.285, 'compound': 0.9843},
#  'B01DEWVZ2C': {'neg': 0.054, 'neu': 0.816, 'pos': 0.13, 'compound': 0.9431},
#  'B0BMGB3CH9': {'neg': 0.037, 'neu': 0.788, 'pos': 0.175, 'compound': 0.9977},
#  'B08D77XZX5': {'neg': 0.058, 'neu': 0.718, 'pos': 0.224, 'compound': 0.9855},
#  'B09XB8GFBQ': {'neg': 0.123, 'neu': 0.761, 'pos': 0.116, 'compound': -0.0516},
#  'B07WG8PDCW': {'neg': 0.0, 'neu': 0.797, 'pos': 0.203, 'compound': 0.9481},
#  'B07GPXXNNG': {'neg': 0.034, 'neu': 0.749, 'pos': 0.216, 'compound': 0.9808},
#  'B0BDYVC5TD': {'neg': 0.02, 'neu': 0.841, 'pos': 0.139, 'compound': 0.85},
#  'B0BMGB2TPR': {'neg': 0.037, 'neu': 0.788, 'pos': 0.175, 'compound': 0.9977},
#  'B08MC57J31': {'neg': 0.018, 'neu': 0.795, 'pos': 0.187, 'compound': 0.9898},
#  'B08HVL8QN3': {'neg': 0.009, 'neu': 0.858, 'pos': 0.133, 'compound': 0.9883},
#  'B0746JGVDS': {'neg': 0.041, 'neu': 0.766, 'pos': 0.193, 'compound': 0.9894},
#  'B08VFF6JQ8': {'neg': 0.059, 'neu': 0.841, 'pos': 0.1, 'compound': 0.7958},
#  'B09NVPSCQT': {'neg': 0.057, 'neu': 0.831, 'pos': 0.112, 'compound': 0.7254},
#  'B09YV4RG4D': {'neg': 0.01, 'neu': 0.791, 'pos': 0.199, 'compound': 0.9921},
#  'B09TWHTBKQ': {'neg': 0.036, 'neu': 0.799, 'pos': 0.165, 'compound': 0.9998},
#  'B08L5HMJVW': {'neg': 0.02, 'neu': 0.841, 'pos': 0.139, 'compound': 0.85},
#  'B0B4F2XCK3': {'neg': 0.038, 'neu': 0.797, 'pos': 0.165, 'compound': 0.9973},
#  'B0BF54972T': {'neg': 0.05, 'neu': 0.802, 'pos': 0.148, 'compound': 0.9952},
#  'B09YV4MW2T': {'neg': 0.057, 'neu': 0.708, 'pos': 0.235, 'compound': 0.9972},
#  'B09TWH8YHM': {'neg': 0.036, 'neu': 0.799, 'pos': 0.165, 'compound': 0.9998},
#  'B07WGMMQGP': {'neg': 0.028, 'neu': 0.804, 'pos': 0.168, 'compound': 0.9385},
#  'B0BF563HB4': {'neg': 0.05, 'neu': 0.802, 'pos': 0.148, 'compound': 0.9952},
#  'B09GFPVD9Y': {'neg': 0.039, 'neu': 0.816, 'pos': 0.145, 'compound': 0.9546},
#  'B09GFLXVH9': {'neg': 0.039, 'neu': 0.816, 'pos': 0.145, 'compound': 0.9546},
#  'B0BF4YBLPX': {'neg': 0.05, 'neu': 0.802, 'pos': 0.148, 'compound': 0.9952},
#  'B09XB7DPW1': {'neg': 0.123, 'neu': 0.761, 'pos': 0.116, 'compound': -0.0516},
#  'B07PFJ5W31': {'neg': 0.051, 'neu': 0.77, 'pos': 0.178, 'compound': 0.8852},
#  'B0B3N7LR6K': {'neg': 0.021, 'neu': 0.792, 'pos': 0.188, 'compound': 0.9995},
#  'B09ZQK9X8G': {'neg': 0.026, 'neu': 0.87, 'pos': 0.105, 'compound': 0.8923},
#  'B07WJV6P1R': {'neg': 0.045, 'neu': 0.788, 'pos': 0.167, 'compound': 0.9726},
#  'B0BF54LXW6': {'neg': 0.05, 'neu': 0.802, 'pos': 0.148, 'compound': 0.9952},
#  'B09XB7SRQ5': {'neg': 0.123, 'neu': 0.761, 'pos': 0.116, 'compound': -0.0516},
#  'B09FFK1PQG': {'neg': 0.0, 'neu': 0.801, 'pos': 0.199, 'compound': 0.9545},
#  'B09RMQYHLH': {'neg': 0.079, 'neu': 0.823, 'pos': 0.098, 'compound': 0.9315},
#  'B08ZN4B121': {'neg': 0.03, 'neu': 0.795, 'pos': 0.175, 'compound': 0.9945},
#  'B0B3RSDSZ3': {'neg': 0.035, 'neu': 0.751, 'pos': 0.214, 'compound': 0.9995},
#  'B08VB34KJ1': {'neg': 0.04, 'neu': 0.703, 'pos': 0.257, 'compound': 0.9486},
#  'B09T39K9YL': {'neg': 0.049, 'neu': 0.754, 'pos': 0.197, 'compound': 0.9985},
#  'B08VF8V79P': {'neg': 0.103, 'neu': 0.758, 'pos': 0.139, 'compound': 0.8307},
#  'B08G28Z33M': {'neg': 0.014, 'neu': 0.764, 'pos': 0.221, 'compound': 0.9565},
#  'B09PNKXSKF': {'neg': 0.057, 'neu': 0.831, 'pos': 0.112, 'compound': 0.7254},
#  'B0B5DDJNH4': {'neg': 0.04, 'neu': 0.725, 'pos': 0.235, 'compound': 0.999},
#  'B07WDKLDRX': {'neg': 0.069, 'neu': 0.806, 'pos': 0.125, 'compound': 0.9985},
#  'B09MQSCJQ1': {'neg': 0.021, 'neu': 0.783, 'pos': 0.196, 'compound': 0.9809},
#  'B094YFFSMY': {'neg': 0.0, 'neu': 0.869, 'pos': 0.131, 'compound': 0.9587},
#  'B09MT84WV5': {'neg': 0.066, 'neu': 0.798, 'pos': 0.136, 'compound': 0.9398},
#  'B08VS3YLRK': {'neg': 0.027, 'neu': 0.692, 'pos': 0.28, 'compound': 0.9701},
#  'B0B4F3QNDM': {'neg': 0.038, 'neu': 0.797, 'pos': 0.165, 'compound': 0.9973},
#  'B07GQD4K6L': {'neg': 0.034, 'neu': 0.749, 'pos': 0.216, 'compound': 0.9808},
#  'B07WDKLRM4': {'neg': 0.045, 'neu': 0.788, 'pos': 0.167, 'compound': 0.9726},
#  'B0BP18W8TM': {'neg': 0.031, 'neu': 0.845, 'pos': 0.124, 'compound': 0.9747},
#  'B07GXHC691': {'neg': 0.077, 'neu': 0.715, 'pos': 0.208, 'compound': 0.9851},
#  'B08FN6WGDQ': {'neg': 0.059, 'neu': 0.752, 'pos': 0.189, 'compound': 0.9989},
#  'B0B3D39RKV': {'neg': 0.08, 'neu': 0.775, 'pos': 0.145, 'compound': 0.997},
#  'B085HY1DGR': {'neg': 0.021, 'neu': 0.737, 'pos': 0.242, 'compound': 0.9819},
#  'B08D75R3Z1': {'neg': 0.027, 'neu': 0.801, 'pos': 0.172, 'compound': 0.9985},
#  'B0B4F2TTTS': {'neg': 0.038, 'neu': 0.797, 'pos': 0.165, 'compound': 0.9973},
#  'B09WRMNJ9G': {'neg': 0.082, 'neu': 0.761, 'pos': 0.157, 'compound': 0.9982},
#  'B0B14MR9L1': {'neg': 0.036, 'neu': 0.799, 'pos': 0.165, 'compound': 0.9998},
#  'B09ZPL5VYM': {'neg': 0.0, 'neu': 0.853, 'pos': 0.147, 'compound': 0.8165},
#  'B0993BB11X': {'neg': 0.062, 'neu': 0.759, 'pos': 0.179, 'compound': 0.9754},
#  'B09V2PZDX8': {'neg': 0.06, 'neu': 0.701, 'pos': 0.239, 'compound': 0.9897},
#  'B085W8CFLH': {'neg': 0.086, 'neu': 0.779, 'pos': 0.135, 'compound': 0.8796},
#  'B09MT6XSFW': {'neg': 0.067, 'neu': 0.802, 'pos': 0.131, 'compound': 0.9144},
#  'B07RD611Z8': {'neg': 0.051, 'neu': 0.833, 'pos': 0.116, 'compound': 0.9981},
#  'B0B4F52B5X': {'neg': 0.038, 'neu': 0.797, 'pos': 0.165, 'compound': 0.9973},
#  'B096VF5YYF': {'neg': 0.05, 'neu': 0.799, 'pos': 0.152, 'compound': 0.9997},
#  'B0B5D39BCD': {'neg': 0.04, 'neu': 0.725, 'pos': 0.235, 'compound': 0.999},
#  'B09XBJ1CTN': {'neg': 0.048, 'neu': 0.754, 'pos': 0.198, 'compound': 0.984},
#  'B0B4F5L738': {'neg': 0.038, 'neu': 0.797, 'pos': 0.165, 'compound': 0.9973},
#  'B08MTCKDYN': {'neg': 0.0, 'neu': 0.831, 'pos': 0.169, 'compound': 0.8625},
#  'B09QS8V5N8': {'neg': 0.035, 'neu': 0.773, 'pos': 0.192, 'compound': 0.9998},
#  'B09T2WRLJJ': {'neg': 0.049, 'neu': 0.754, 'pos': 0.197, 'compound': 0.9985},
#  'B089WB69Y1': {'neg': 0.074, 'neu': 0.793, 'pos': 0.133, 'compound': 0.8394},
#  'B0116MIKKC': {'neg': 0.0, 'neu': 0.788, 'pos': 0.212, 'compound': 0.9522},
#  'B09P858DK8': {'neg': 0.048, 'neu': 0.741, 'pos': 0.212, 'compound': 0.9796},
#  'B07DJLFMPS': {'neg': 0.12, 'neu': 0.68, 'pos': 0.2, 'compound': 0.7184},
#  'B07WHQWXL7': {'neg': 0.045, 'neu': 0.788, 'pos': 0.167, 'compound': 0.9726},
#  'B07WDK3ZS6': {'neg': 0.045, 'neu': 0.788, 'pos': 0.167, 'compound': 0.9726},
#  'B09T2S8X9C': {'neg': 0.049, 'neu': 0.754, 'pos': 0.197, 'compound': 0.9985},
#  'B07S9S86BF': {'neg': 0.064, 'neu': 0.704, 'pos': 0.232, 'compound': 0.9857},
#  'B07N8RQ6W7': {'neg': 0.0, 'neu': 0.847, 'pos': 0.153, 'compound': 0.7964},
#  'B09FKDH6FS': {'neg': 0.047, 'neu': 0.777, 'pos': 0.175, 'compound': 0.8814},
#  'B08HVJCW95': {'neg': 0.009, 'neu': 0.858, 'pos': 0.133, 'compound': 0.9883},
#  'B09YDFDVNS': {'neg': 0.06, 'neu': 0.701, 'pos': 0.239, 'compound': 0.9897},
#  'B07WGPKTS4': {'neg': 0.045, 'neu': 0.788, 'pos': 0.167, 'compound': 0.9726},
#  'B09MZCQYHZ': {'neg': 0.062, 'neu': 0.759, 'pos': 0.179, 'compound': 0.9754},
#  'B0B4F2ZWL3': {'neg': 0.038, 'neu': 0.797, 'pos': 0.165, 'compound': 0.9973},
#  'B08VB2CMR3': {'neg': 0.04, 'neu': 0.703, 'pos': 0.257, 'compound': 0.9486},
#  'B095RTJH1M': {'neg': 0.031, 'neu': 0.728, 'pos': 0.241, 'compound': 0.9987},
#  'B097R25DP7': {'neg': 0.055, 'neu': 0.788, 'pos': 0.157, 'compound': 0.8957},
#  'B09YDFKJF8': {'neg': 0.06, 'neu': 0.701, 'pos': 0.239, 'compound': 0.9897},
#  'B07WDK3ZS2': {'neg': 0.017, 'neu': 0.86, 'pos': 0.123, 'compound': 0.9764},
#  'B08RZ5K9YH': {'neg': 0.028, 'neu': 0.735, 'pos': 0.237, 'compound': 0.9429},
#  'B08444S68L': {'neg': 0.021, 'neu': 0.828, 'pos': 0.151, 'compound': 0.9525},
#  'B07WHQBZLS': {'neg': 0.028, 'neu': 0.804, 'pos': 0.168, 'compound': 0.9385},
#  'B09JS562TP': {'neg': 0.069, 'neu': 0.79, 'pos': 0.142, 'compound': 0.5994},
#  'B09V17S2BG': {'neg': 0.0, 'neu': 0.738, 'pos': 0.262, 'compound': 0.9459},
#  'B0B5CGTBKV': {'neg': 0.04, 'neu': 0.725, 'pos': 0.235, 'compound': 0.999},
#  'B0B23LW7NV': {'neg': 0.02, 'neu': 0.772, 'pos': 0.209, 'compound': 0.9961},
#  'B09KGV7WSV': {'neg': 0.029, 'neu': 0.768, 'pos': 0.203, 'compound': 0.9963},
#  'B0971DWFDT': {'neg': 0.044, 'neu': 0.828, 'pos': 0.128, 'compound': 0.9278},
#  'B0BNV7JM5Y': {'neg': 0.06, 'neu': 0.715, 'pos': 0.226, 'compound': 0.9936},
#  'B0B53QFZPY': {'neg': 0.123, 'neu': 0.831, 'pos': 0.045, 'compound': -0.607},
#  'B07WJWRNVK': {'neg': 0.028, 'neu': 0.804, 'pos': 0.168, 'compound': 0.9385},
#  'B01F25X6RQ': {'neg': 0.071, 'neu': 0.704, 'pos': 0.225, 'compound': 0.9593},
#  'B0B244R4KB': {'neg': 0.018, 'neu': 0.759, 'pos': 0.222, 'compound': 0.998},
#  'B0BMGG6NKT': {'neg': 0.037, 'neu': 0.788, 'pos': 0.175, 'compound': 0.9977},
#  'B092JHPL72': {'neg': 0.0, 'neu': 0.779, 'pos': 0.221, 'compound': 0.9807},
#  'B09GFM8CGS': {'neg': 0.039, 'neu': 0.816, 'pos': 0.145, 'compound': 0.9546},
#  'B0B3MWYCHQ': {'neg': 0.019, 'neu': 0.823, 'pos': 0.158, 'compound': 0.9921},
#  'B09J2MM5C6': {'neg': 0.052, 'neu': 0.612, 'pos': 0.336, 'compound': 0.9966},
#  'B07Q4QV1DL': {'neg': 0.0, 'neu': 0.682, 'pos': 0.318, 'compound': 0.984},
#  'B0B56YRBNT': {'neg': 0.0, 'neu': 0.766, 'pos': 0.234, 'compound': 0.8979},
#  'B01DF26V7A': {'neg': 0.054, 'neu': 0.816, 'pos': 0.13, 'compound': 0.9431},
#  'B08K4PSZ3V': {'neg': 0.057, 'neu': 0.728, 'pos': 0.215, 'compound': 0.9882},
#  'B0B4F1YC3J': {'neg': 0.038, 'neu': 0.797, 'pos': 0.165, 'compound': 0.9973},
#  'B08K4RDQ71': {'neg': 0.057, 'neu': 0.728, 'pos': 0.215, 'compound': 0.9882},
#  'B085CZ3SR1': {'neg': 0.024, 'neu': 0.895, 'pos': 0.081, 'compound': 0.6369},
#  'B09YV3K34W': {'neg': 0.059, 'neu': 0.71, 'pos': 0.232, 'compound': 0.9968},
#  'B09Z6WH2N1': {'neg': 0.01, 'neu': 0.833, 'pos': 0.157, 'compound': 0.9574},
#  'B09NL4DJ2Z': {'neg': 0.0, 'neu': 0.713, 'pos': 0.287, 'compound': 0.9817},
#  'B0BGSV43WY': {'neg': 0.052, 'neu': 0.885, 'pos': 0.063, 'compound': 0.2598},
#  'B0926V9CTV': {'neg': 0.093, 'neu': 0.717, 'pos': 0.19, 'compound': 0.947},
#  'B07WGPKMP5': {'neg': 0.045, 'neu': 0.788, 'pos': 0.167, 'compound': 0.9726},
#  'B0BBFJ9M3X': {'neg': 0.02, 'neu': 0.91, 'pos': 0.069, 'compound': 0.6689},
#  'B09PLFJ7ZW': {'neg': 0.05, 'neu': 0.731, 'pos': 0.22, 'compound': 0.9815},
#  'B0B53NXFFR': {'neg': 0.123, 'neu': 0.831, 'pos': 0.045, 'compound': -0.607},
#  'B07GNC2592': {'neg': 0.076, 'neu': 0.808, 'pos': 0.117, 'compound': 0.9069},
#  'B09TP5KBN7': {'neg': 0.05, 'neu': 0.711, 'pos': 0.238, 'compound': 0.9134},
#  'B0949SBKMP': {'neg': 0.023, 'neu': 0.758, 'pos': 0.219, 'compound': 0.9931},
#  'B09V175NP7': {'neg': 0.0, 'neu': 0.738, 'pos': 0.262, 'compound': 0.9459},
#  'B07WHSJXLF': {'neg': 0.017, 'neu': 0.86, 'pos': 0.123, 'compound': 0.9764},
#  'B0BD3T6Z1D': {'neg': 0.057, 'neu': 0.807, 'pos': 0.136, 'compound': 0.9979},
#  'B09LHYZ3GJ': {'neg': 0.053, 'neu': 0.719, 'pos': 0.227, 'compound': 0.9973},
#  'B07WFPMGQQ': {'neg': 0.017, 'neu': 0.86, 'pos': 0.123, 'compound': 0.9764},
#  'B09QS9X9L8': {'neg': 0.035, 'neu': 0.773, 'pos': 0.192, 'compound': 0.9998},
#  'B0B6BLTGTT': {'neg': 0.024, 'neu': 0.819, 'pos': 0.157, 'compound': 0.9876},
#  'B084DTMYWK': {'neg': 0.054, 'neu': 0.752, 'pos': 0.194, 'compound': 0.9611},
#  'B0B53QLB9H': {'neg': 0.123, 'neu': 0.831, 'pos': 0.045, 'compound': -0.607},
#  'B0BDYW3RN3': {'neg': 0.02, 'neu': 0.841, 'pos': 0.139, 'compound': 0.85},
#  'B0B3RS9DNF': {'neg': 0.035, 'neu': 0.751, 'pos': 0.214, 'compound': 0.9995},
#  'B09QS9X16F': {'neg': 0.035, 'neu': 0.773, 'pos': 0.192, 'compound': 0.9998},
#  'B08HV25BBQ': {'neg': 0.0, 'neu': 0.676, 'pos': 0.324, 'compound': 0.8995},
#  'B09LJ116B5': {'neg': 0.053, 'neu': 0.719, 'pos': 0.227, 'compound': 0.9973},
#  'B0BMVWKZ8G': {'neg': 0.132, 'neu': 0.868, 'pos': 0.0, 'compound': -0.8622},
#  'B0BD92GDQH': {'neg': 0.073, 'neu': 0.777, 'pos': 0.15, 'compound': 0.9727},
#  'B0B5GF6DQD': {'neg': 0.051, 'neu': 0.742, 'pos': 0.208, 'compound': 0.8126},
#  'B09JS94MBV': {'neg': 0.069, 'neu': 0.79, 'pos': 0.142, 'compound': 0.5994},
#  'B09YV463SW': {'neg': 0.01, 'neu': 0.791, 'pos': 0.199, 'compound': 0.9921},
#  'B09NL4DCXK': {'neg': 0.0, 'neu': 0.797, 'pos': 0.203, 'compound': 0.9366},
#  'B0B8CHJLWJ': {'neg': 0.093, 'neu': 0.695, 'pos': 0.213, 'compound': 0.9854},
#  'B0B8ZWNR5T': {'neg': 0.01, 'neu': 0.833, 'pos': 0.157, 'compound': 0.9574},
#  'B0BBFJLP21': {'neg': 0.021, 'neu': 0.907, 'pos': 0.072, 'compound': 0.6689},
#  'B01F262EUU': {'neg': 0.071, 'neu': 0.704, 'pos': 0.225, 'compound': 0.9593},
#  'B09VZBGL1N': {'neg': 0.0, 'neu': 0.683, 'pos': 0.317, 'compound': 0.936},
#  'B0BNVBJW2S': {'neg': 0.06, 'neu': 0.715, 'pos': 0.226, 'compound': 0.9936},
#  'B0B2DJ5RVQ': {'neg': 0.075, 'neu': 0.702, 'pos': 0.223, 'compound': 0.9751},
#  'B096TWZRJC': {'neg': 0.078, 'neu': 0.764, 'pos': 0.158, 'compound': 0.9864},
#  'B09GP6FBZT': {'neg': 0.011, 'neu': 0.752, 'pos': 0.238, 'compound': 0.9982},
#  'B0B3DV7S9B': {'neg': 0.135, 'neu': 0.513, 'pos': 0.352, 'compound': 0.9081},
#  'B09MKP344P': {'neg': 0.162, 'neu': 0.681, 'pos': 0.156, 'compound': -0.1435},
#  'B08JW1GVS7': {'neg': 0.077, 'neu': 0.832, 'pos': 0.091, 'compound': 0.8861},
#  'B09LHZSMRR': {'neg': 0.053, 'neu': 0.719, 'pos': 0.227, 'compound': 0.9973},
#  'B0B5V47VK4': {'neg': 0.063, 'neu': 0.732, 'pos': 0.204, 'compound': 0.9996},
#  'B08H21B6V7': {'neg': 0.035, 'neu': 0.68, 'pos': 0.285, 'compound': 0.9933},
#  'B09BNXQ6BR': {'neg': 0.071, 'neu': 0.828, 'pos': 0.102, 'compound': 0.8573},
#  'B01FSYQ2A4': {'neg': 0.081, 'neu': 0.774, 'pos': 0.145, 'compound': 0.9991},
#  'B08L5FM4JC': {'neg': 0.02, 'neu': 0.841, 'pos': 0.139, 'compound': 0.85},
#  'B0B54Y2SNX': {'neg': 0.045, 'neu': 0.719, 'pos': 0.236, 'compound': 0.9581},
#  'B08BQ947H3': {'neg': 0.05, 'neu': 0.836, 'pos': 0.113, 'compound': 0.9981},
#  'B0B7DHSKS7': {'neg': 0.114, 'neu': 0.773, 'pos': 0.113, 'compound': 0.6539},
#  'B09SJ1FTYV': {'neg': 0.0, 'neu': 0.58, 'pos': 0.42, 'compound': 0.9829},
#  'B09XJ5LD6L': {'neg': 0.075, 'neu': 0.794, 'pos': 0.131, 'compound': 0.9974},
#  'B07WHS7MZ1': {'neg': 0.076, 'neu': 0.771, 'pos': 0.154, 'compound': 0.9984},
#  'B0BBVKRP7B': {'neg': 0.059, 'neu': 0.844, 'pos': 0.098, 'compound': 0.4201},
#  'B09NY7W8YD': {'neg': 0.032, 'neu': 0.801, 'pos': 0.167, 'compound': 0.8466},
#  'B0BMM7R92G': {'neg': 0.024, 'neu': 0.574, 'pos': 0.403, 'compound': 0.9844},
#  'B08M66K48D': {'neg': 0.037, 'neu': 0.723, 'pos': 0.24, 'compound': 0.9944},
#  'B09RFB2SJQ': {'neg': 0.0, 'neu': 0.683, 'pos': 0.317, 'compound': 0.984},
#  'B0B82YGCF6': {'neg': 0.063, 'neu': 0.829, 'pos': 0.108, 'compound': 0.7245},
#  'B08HF4W2CT': {'neg': 0.129, 'neu': 0.769, 'pos': 0.103, 'compound': -0.4467},
#  'B08BCKN299': {'neg': 0.07, 'neu': 0.838, 'pos': 0.092, 'compound': 0.5127},
#  'B0B2X35B1K': {'neg': 0.121, 'neu': 0.703, 'pos': 0.176, 'compound': 0.8972},
#  'B09QS9CWLV': {'neg': 0.035, 'neu': 0.773, 'pos': 0.192, 'compound': 0.9998},
#  'B0B1NX6JTN': {'neg': 0.025, 'neu': 0.853, 'pos': 0.122, 'compound': 0.9473},
#  'B078G6ZF5Z': {'neg': 0.074, 'neu': 0.793, 'pos': 0.133, 'compound': 0.8394},
#  'B0BBW521YC': {'neg': 0.097, 'neu': 0.691, 'pos': 0.212, 'compound': 0.9625},
#  'B09HSKYMB3': {'neg': 0.0, 'neu': 0.893, 'pos': 0.107, 'compound': 0.629},
#  'B09YV42QHZ': {'neg': 0.01, 'neu': 0.791, 'pos': 0.199, 'compound': 0.9921},
#  'B09BF8JBWX': {'neg': 0.086, 'neu': 0.61, 'pos': 0.303, 'compound': 0.723},
#  'B0B5YBGCKD': {'neg': 0.048, 'neu': 0.81, 'pos': 0.141, 'compound': 0.9858},
#  'B09MY4W73Q': {'neg': 0.029, 'neu': 0.771, 'pos': 0.201, 'compound': 0.9873},
#  'B09T37CKQ5': {'neg': 0.0, 'neu': 0.797, 'pos': 0.203, 'compound': 0.9366},
#  'B09GFPN6TP': {'neg': 0.039, 'neu': 0.816, 'pos': 0.145, 'compound': 0.9546},
#  'B0B298D54H': {'neg': 0.074, 'neu': 0.788, 'pos': 0.138, 'compound': 0.9413},
#  'B08VB57558': {'neg': 0.059, 'neu': 0.782, 'pos': 0.16, 'compound': 0.9997},
#  'B0B9BXKBC7': {'neg': 0.012, 'neu': 0.737, 'pos': 0.251, 'compound': 0.9942},
#  'B09NY6TRXG': {'neg': 0.097, 'neu': 0.798, 'pos': 0.105, 'compound': 0.383},
#  'B09NVPJ3P4': {'neg': 0.057, 'neu': 0.831, 'pos': 0.112, 'compound': 0.7254},
#  'B0B3NDPCS9': {'neg': 0.021, 'neu': 0.792, 'pos': 0.188, 'compound': 0.9995},
#  'B09VGKFM7Y': {'neg': 0.093, 'neu': 0.705, 'pos': 0.203, 'compound': 0.3612},
#  'B07QCWY5XV': {'neg': 0.017, 'neu': 0.874, 'pos': 0.109, 'compound': 0.9266},
#  'B098QXR9X2': {'neg': 0.044, 'neu': 0.848, 'pos': 0.108, 'compound': 0.9489},
#  'B07H1S7XW8': {'neg': 0.011, 'neu': 0.835, 'pos': 0.153, 'compound': 0.9495},
#  'B0BNXFDTZ2': {'neg': 0.042, 'neu': 0.818, 'pos': 0.14, 'compound': 0.9906},
#  'B088ZFJY82': {'neg': 0.0, 'neu': 0.682, 'pos': 0.318, 'compound': 0.984},
#  'B0B4F4QZ1H': {'neg': 0.038, 'neu': 0.797, 'pos': 0.165, 'compound': 0.9973},
#  'B09BCNQ9R2': {'neg': 0.032, 'neu': 0.83, 'pos': 0.138, 'compound': 0.8792},
#  'B0B9BD2YL4': {'neg': 0.054, 'neu': 0.708, 'pos': 0.239, 'compound': 0.9971},
#  'B071Z8M4KX': {'neg': 0.034, 'neu': 0.749, 'pos': 0.216, 'compound': 0.9808},
#  'B09N3ZNHTY': {'neg': 0.037, 'neu': 0.797, 'pos': 0.166, 'compound': 0.9993},
#  'B005FYNT3G': {'neg': 0.056, 'neu': 0.696, 'pos': 0.248, 'compound': 0.8008},
#  'B01J0XWYKQ': {'neg': 0.07, 'neu': 0.776, 'pos': 0.154, 'compound': 0.9981},
#  'B09CTRPSJR': {'neg': 0.011, 'neu': 0.79, 'pos': 0.198, 'compound': 0.9829},
#  'B08JQN8DGZ': {'neg': 0.072, 'neu': 0.82, 'pos': 0.108, 'compound': 0.9747},
#  'B0B72BSW7K': {'neg': 0.077, 'neu': 0.707, 'pos': 0.216, 'compound': 0.988},
#  'B08TV2P1N8': {'neg': 0.053, 'neu': 0.729, 'pos': 0.218, 'compound': 0.999},
#  'B07XCM6T4N': {'neg': 0.026, 'neu': 0.817, 'pos': 0.157, 'compound': 0.8817},
#  'B07T5DKR5D': {'neg': 0.05, 'neu': 0.739, 'pos': 0.211, 'compound': 0.985},
#  'B07PR1CL3S': {'neg': 0.011, 'neu': 0.814, 'pos': 0.175, 'compound': 0.9814},
#  'B07JQKQ91F': {'neg': 0.018, 'neu': 0.704, 'pos': 0.278, 'compound': 0.9991},
#  'B08W56G1K9': {'neg': 0.021, 'neu': 0.792, 'pos': 0.187, 'compound': 0.9764},
#  'B01L8ZNWN2': {'neg': 0.053, 'neu': 0.836, 'pos': 0.111, 'compound': 0.9952},
#  'B009VCGPSY': {'neg': 0.015, 'neu': 0.806, 'pos': 0.179, 'compound': 0.9627},
#  'B0B296NTFV': {'neg': 0.018, 'neu': 0.744, 'pos': 0.238, 'compound': 0.9949},
#  'B07TCN5VR9': {'neg': 0.032, 'neu': 0.81, 'pos': 0.158, 'compound': 0.9956},
#  'B00ZYLMQH0': {'neg': 0.095, 'neu': 0.796, 'pos': 0.109, 'compound': 0.381},
#  'B01HJI0FS2': {'neg': 0.11, 'neu': 0.816, 'pos': 0.073, 'compound': -0.838},
#  'B076B8G5D8': {'neg': 0.081, 'neu': 0.799, 'pos': 0.12, 'compound': 0.9941},
#  'B014SZO90Y': {'neg': 0.0, 'neu': 0.744, 'pos': 0.256, 'compound': 0.9477},
#  'B07KCMR8D6': {'neg': 0.0, 'neu': 0.652, 'pos': 0.348, 'compound': 0.9735},
#  'B00N1U9AJS': {'neg': 0.0, 'neu': 0.806, 'pos': 0.194, 'compound': 0.8703},
#  'B07KY3FNQP': {'neg': 0.045, 'neu': 0.834, 'pos': 0.121, 'compound': 0.9983},
#  'B07QZ3CZ48': {'neg': 0.108, 'neu': 0.647, 'pos': 0.245, 'compound': 0.9464},
#  'B09T3H12GV': {'neg': 0.039, 'neu': 0.824, 'pos': 0.137, 'compound': 0.9735},
#  'B08ZJDWTJ1': {'neg': 0.0, 'neu': 0.792, 'pos': 0.208, 'compound': 0.6757},
#  'B08FTFXNNB': {'neg': 0.098, 'neu': 0.746, 'pos': 0.156, 'compound': 0.8687},
#  'B08YDFX7Y1': {'neg': 0.083, 'neu': 0.72, 'pos': 0.197, 'compound': 0.9668},
#  'B087FXHB6J': {'neg': 0.008, 'neu': 0.908, 'pos': 0.084, 'compound': 0.926},
#  'B07N42JB4S': {'neg': 0.009, 'neu': 0.69, 'pos': 0.301, 'compound': 0.9945},
#  'B0B31BYXQQ': {'neg': 0.013, 'neu': 0.751, 'pos': 0.236, 'compound': 0.9837},
#  'B07SLMR1K6': {'neg': 0.014, 'neu': 0.79, 'pos': 0.196, 'compound': 0.9923},
#  'B092X94QNQ': {'neg': 0.035, 'neu': 0.787, 'pos': 0.178, 'compound': 0.9998},
#  'B0846D5CBP': {'neg': 0.045, 'neu': 0.613, 'pos': 0.342, 'compound': 0.9842},
#  'B00KXULGJQ': {'neg': 0.029, 'neu': 0.73, 'pos': 0.241, 'compound': 0.9961},
#  'B08H9Z3XQW': {'neg': 0.064, 'neu': 0.704, 'pos': 0.232, 'compound': 0.9857},
#  'B08LPJZSSW': {'neg': 0.019, 'neu': 0.831, 'pos': 0.15, 'compound': 0.9912},
#  'B08CYPB15D': {'neg': 0.041, 'neu': 0.757, 'pos': 0.202, 'compound': 0.8559},
#  'B00MFPCY5C': {'neg': 0.018, 'neu': 0.781, 'pos': 0.201, 'compound': 0.9647},
#  'B07JJFSG2B': {'neg': 0.0, 'neu': 0.828, 'pos': 0.172, 'compound': 0.926},
#  'B09NR6G588': {'neg': 0.095, 'neu': 0.779, 'pos': 0.126, 'compound': 0.9192},
#  'B07JPX9CR7': {'neg': 0.045, 'neu': 0.806, 'pos': 0.15, 'compound': 0.8977},
#  'B08D11DZ2W': {'neg': 0.064, 'neu': 0.806, 'pos': 0.13, 'compound': 0.998},
#  'B07Q7561HD': {'neg': 0.0, 'neu': 0.921, 'pos': 0.079, 'compound': 0.3384},
#  'B0819HZPXL': {'neg': 0.058, 'neu': 0.71, 'pos': 0.232, 'compound': 0.9941},
#  'B00LXTFMRS': {'neg': 0.0, 'neu': 0.715, 'pos': 0.285, 'compound': 0.994},
#  'B0B9LDCX89': {'neg': 0.011, 'neu': 0.701, 'pos': 0.288, 'compound': 0.9882},
#  'B0765B3TH7': {'neg': 0.028, 'neu': 0.7, 'pos': 0.272, 'compound': 0.9633},
#  'B0B1F6GQPS': {'neg': 0.079, 'neu': 0.735, 'pos': 0.185, 'compound': 0.9569},
#  'B07LG59NPV': {'neg': 0.021, 'neu': 0.838, 'pos': 0.141, 'compound': 0.9998},
#  'B00AXHBBXU': {'neg': 0.0, 'neu': 0.779, 'pos': 0.221, 'compound': 0.8032},
#  'B08MCD9JFY': {'neg': 0.062, 'neu': 0.694, 'pos': 0.244, 'compound': 0.9754},
#  'B083RCTXLL': {'neg': 0.079, 'neu': 0.847, 'pos': 0.073, 'compound': -0.2614},
#  'B08HLZ28QC': {'neg': 0.059, 'neu': 0.783, 'pos': 0.158, 'compound': 0.9973},
#  'B07GVR9TG7': {'neg': 0.033, 'neu': 0.802, 'pos': 0.165, 'compound': 0.9949},
# ...
#  'B07YNHCW6N': {'neg': 0.055, 'neu': 0.804, 'pos': 0.142, 'compound': 0.8209},
#  'B01MQ2A86A': {'neg': 0.028, 'neu': 0.73, 'pos': 0.242, 'compound': 0.9944},
#  'B00KIE28X0': {'neg': 0.0, 'neu': 0.578, 'pos': 0.422, 'compound': 0.8591},
#  'B0BHYJ8CVF': {'neg': 0.037, 'neu': 0.819, 'pos': 0.144, 'compound': 0.9894},
#  'B0BCVJ3PVP': {'neg': 0.0, 'neu': 0.8, 'pos': 0.2, 'compound': 0.9771},
#  'B0B2931FCV': {'neg': 0.039, 'neu': 0.768, 'pos': 0.193, 'compound': 0.9818},
#  'B09TMZ1MF8': {'neg': 0.058, 'neu': 0.669, 'pos': 0.273, 'compound': 0.9909},
#  'B07VV37FT4': {'neg': 0.035, 'neu': 0.869, 'pos': 0.096, 'compound': 0.5423},
#  'B07JB2Y4SR': {'neg': 0.19, 'neu': 0.657, 'pos': 0.153, 'compound': -0.5688},
#  'B08KRMK9LZ': {'neg': 0.045, 'neu': 0.769, 'pos': 0.186, 'compound': 0.9755},
#  'B08LT9BMPP': {'neg': 0.056, 'neu': 0.748, 'pos': 0.197, 'compound': 0.9964},
#  'B0814ZY6FP': {'neg': 0.12, 'neu': 0.725, 'pos': 0.155, 'compound': 0.8894},
#  'B09F3PDDRF': {'neg': 0.032, 'neu': 0.809, 'pos': 0.158, 'compound': 0.9923},
#  'B07X963JNS': {'neg': 0.129, 'neu': 0.769, 'pos': 0.103, 'compound': -0.4467},
#  'B09LD3116F': {'neg': 0.042, 'neu': 0.834, 'pos': 0.123, 'compound': 0.9822},
#  'B08Y5QJTVK': {'neg': 0.026, 'neu': 0.858, 'pos': 0.115, 'compound': 0.8715},
#  'B00LY1FN1K': {'neg': 0.0, 'neu': 0.79, 'pos': 0.21, 'compound': 0.91},
#  'B07DJ5KYDZ': {'neg': 0.061, 'neu': 0.82, 'pos': 0.119, 'compound': 0.8682},
#  'B009LJ2BXA': {'neg': 0.15, 'neu': 0.683, 'pos': 0.168, 'compound': 0.7204},
#  'B09BVCVTBC': {'neg': 0.031, 'neu': 0.769, 'pos': 0.199, 'compound': 0.9983},
#  'B07SY4C3TD': {'neg': 0.05, 'neu': 0.775, 'pos': 0.175, 'compound': 0.9601},
#  'B094JB13XL': {'neg': 0.071, 'neu': 0.828, 'pos': 0.102, 'compound': 0.8573},
#  'B08CRRQK6Z': {'neg': 0.019, 'neu': 0.793, 'pos': 0.188, 'compound': 0.9975},
#  'B08MTLLSL8': {'neg': 0.0, 'neu': 0.738, 'pos': 0.262, 'compound': 0.9748},
#  'B08Y57TPDM': {'neg': 0.0, 'neu': 0.919, 'pos': 0.081, 'compound': 0.7687},
#  'B09CYTJV3N': {'neg': 0.078, 'neu': 0.798, 'pos': 0.124, 'compound': 0.9842},
#  'B07GLNJC25': {'neg': 0.05, 'neu': 0.783, 'pos': 0.167, 'compound': 0.8336},
#  'B08FY4FG5X': {'neg': 0.034, 'neu': 0.779, 'pos': 0.187, 'compound': 0.9992},
#  'B07TMCXRFV': {'neg': 0.082, 'neu': 0.751, 'pos': 0.167, 'compound': 0.9823},
#  'B00LZPQVMK': {'neg': 0.094, 'neu': 0.789, 'pos': 0.117, 'compound': 0.4215},
#  'B08X77LM8C': {'neg': 0.026, 'neu': 0.724, 'pos': 0.25, 'compound': 0.9912},
#  'B01EJ5MM5M': {'neg': 0.058, 'neu': 0.872, 'pos': 0.071, 'compound': 0.5756},
#  'B08J82K4GX': {'neg': 0.072, 'neu': 0.78, 'pos': 0.147, 'compound': 0.9949},
#  'B07Z1Z77ZZ': {'neg': 0.111, 'neu': 0.744, 'pos': 0.146, 'compound': 0.7767},
#  'B00DJ5N9VK': {'neg': 0.022, 'neu': 0.794, 'pos': 0.184, 'compound': 0.9867},
#  'B08FGNPQ9X': {'neg': 0.08, 'neu': 0.769, 'pos': 0.151, 'compound': 0.9943},
#  'B07NTKGW45': {'neg': 0.017, 'neu': 0.916, 'pos': 0.067, 'compound': 0.8371},
#  'B08J4PL1Z3': {'neg': 0.085, 'neu': 0.821, 'pos': 0.094, 'compound': 0.791},
#  'B07XJWTYM2': {'neg': 0.042, 'neu': 0.759, 'pos': 0.199, 'compound': 0.9999},
#  'B09939XJX8': {'neg': 0.03, 'neu': 0.571, 'pos': 0.4, 'compound': 0.984},
#  'B09MDCZJXS': {'neg': 0.036, 'neu': 0.588, 'pos': 0.377, 'compound': 0.9962},
#  'B08CTQP51L': {'neg': 0.073, 'neu': 0.717, 'pos': 0.209, 'compound': 0.9771},
#  'B0BG62HMDJ': {'neg': 0.041, 'neu': 0.576, 'pos': 0.383, 'compound': 0.978},
#  'B08GTYFC37': {'neg': 0.047, 'neu': 0.888, 'pos': 0.065, 'compound': 0.421},
#  'B08SBH499M': {'neg': 0.057, 'neu': 0.699, 'pos': 0.244, 'compound': 0.9575},
#  'B08FYB5HHK': {'neg': 0.053, 'neu': 0.791, 'pos': 0.156, 'compound': 0.9919},
#  'B0B5GJRTHB': {'neg': 0.134, 'neu': 0.741, 'pos': 0.125, 'compound': 0.3841},
#  'B09GBBJV72': {'neg': 0.014, 'neu': 0.791, 'pos': 0.195, 'compound': 0.9885},
#  'B07P434WJY': {'neg': 0.043, 'neu': 0.698, 'pos': 0.258, 'compound': 0.985},
#  'B07T9FV9YP': {'neg': 0.058, 'neu': 0.801, 'pos': 0.141, 'compound': 0.9892},
#  'B08WKFSN84': {'neg': 0.073, 'neu': 0.622, 'pos': 0.305, 'compound': 0.9895},
#  'B09TBCVJS3': {'neg': 0.04, 'neu': 0.811, 'pos': 0.149, 'compound': 0.9991},
#  'B08TR61BVK': {'neg': 0.025, 'neu': 0.735, 'pos': 0.24, 'compound': 0.9972},
#  'B0B2CPVXHX': {'neg': 0.162, 'neu': 0.686, 'pos': 0.152, 'compound': -0.2942},
#  'B08XNL93PL': {'neg': 0.061, 'neu': 0.803, 'pos': 0.137, 'compound': 0.9796},
#  'B088GXTJM3': {'neg': 0.03, 'neu': 0.715, 'pos': 0.255, 'compound': 0.9776},
#  'B099S26HWG': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  'B08461VC1Z': {'neg': 0.0, 'neu': 0.763, 'pos': 0.237, 'compound': 0.9959},
#  'B00K32PEW4': {'neg': 0.07, 'neu': 0.93, 'pos': 0.0, 'compound': -0.2755},
#  'B07LFWP97N': {'neg': 0.027, 'neu': 0.705, 'pos': 0.268, 'compound': 0.991},
#  'B0746N6WML': {'neg': 0.0, 'neu': 0.677, 'pos': 0.323, 'compound': 0.936},
#  'B07W9KYT62': {'neg': 0.034, 'neu': 0.854, 'pos': 0.112, 'compound': 0.9982},
#  'B08D9MNH4B': {'neg': 0.057, 'neu': 0.878, 'pos': 0.065, 'compound': 0.3244},
#  'B09MKG4ZCM': {'neg': 0.074, 'neu': 0.838, 'pos': 0.088, 'compound': 0.3887},
#  'B07RZZ1QSW': {'neg': 0.061, 'neu': 0.719, 'pos': 0.221, 'compound': 0.9822},
#  'B07222HQKP': {'neg': 0.024, 'neu': 0.811, 'pos': 0.165, 'compound': 0.9881},
#  'B00NFD0ETQ': {'neg': 0.048, 'neu': 0.768, 'pos': 0.184, 'compound': 0.996},
#  'B075DB1F13': {'neg': 0.1, 'neu': 0.782, 'pos': 0.118, 'compound': 0.7725},
#  'B0148NPH9I': {'neg': 0.044, 'neu': 0.806, 'pos': 0.15, 'compound': 0.9991},
#  'B01JOFKL0A': {'neg': 0.079, 'neu': 0.78, 'pos': 0.141, 'compound': 0.9909},
#  'B079S811J3': {'neg': 0.108, 'neu': 0.762, 'pos': 0.13, 'compound': 0.9747},
#  'B0083T231O': {'neg': 0.15, 'neu': 0.694, 'pos': 0.156, 'compound': 0.2393},
#  'B086PXQ2R4': {'neg': 0.108, 'neu': 0.77, 'pos': 0.122, 'compound': -0.0344},
#  'B07L1N3TJX': {'neg': 0.054, 'neu': 0.804, 'pos': 0.143, 'compound': 0.9825},
#  'B07YFWVRCM': {'neg': 0.032, 'neu': 0.849, 'pos': 0.119, 'compound': 0.9813},
#  'B08TDJ5BVF': {'neg': 0.059, 'neu': 0.866, 'pos': 0.075, 'compound': 0.0757},
#  'B09XXZXQC1': {'neg': 0.046, 'neu': 0.822, 'pos': 0.132, 'compound': 0.9996},
#  'B083T5G5PM': {'neg': 0.068, 'neu': 0.777, 'pos': 0.155, 'compound': 0.9995},
#  'B0BHVPTM2C': {'neg': 0.025, 'neu': 0.691, 'pos': 0.284, 'compound': 0.9838},
#  'B01NBX5RSB': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  'B08MWJTST6': {'neg': 0.063, 'neu': 0.806, 'pos': 0.131, 'compound': 0.8826},
#  'B07R99NBVB': {'neg': 0.045, 'neu': 0.782, 'pos': 0.173, 'compound': 0.9928},
#  'B00LY12TH6': {'neg': 0.013, 'neu': 0.813, 'pos': 0.174, 'compound': 0.9347},
#  'B08497Z1MQ': {'neg': 0.102, 'neu': 0.699, 'pos': 0.199, 'compound': 0.8875},
#  'B07KNM95JK': {'neg': 0.0, 'neu': 0.855, 'pos': 0.145, 'compound': 0.3716},
#  'B09Q3M3WLJ': {'neg': 0.023, 'neu': 0.939, 'pos': 0.038, 'compound': -0.0387},
#  'B09B9SPC7F': {'neg': 0.0, 'neu': 0.853, 'pos': 0.147, 'compound': 0.8478},
#  'B099SD8PRP': {'neg': 0.047, 'neu': 0.667, 'pos': 0.286, 'compound': 0.9803},
#  'B00S2SEV7K': {'neg': 0.053, 'neu': 0.784, 'pos': 0.164, 'compound': 0.991},
#  'B08WKCTFF3': {'neg': 0.019, 'neu': 0.831, 'pos': 0.149, 'compound': 0.9842},
#  'B08498D67S': {'neg': 0.075, 'neu': 0.813, 'pos': 0.112, 'compound': 0.9338},
#  'B00C3GBCIS': {'neg': 0.047, 'neu': 0.785, 'pos': 0.169, 'compound': 0.9267},
#  'B00URH5E34': {'neg': 0.04, 'neu': 0.753, 'pos': 0.207, 'compound': 0.7369},
#  'B00EYW1U68': {'neg': 0.058, 'neu': 0.824, 'pos': 0.118, 'compound': 0.9846},
#  'B08SMJT55F': {'neg': 0.094, 'neu': 0.752, 'pos': 0.154, 'compound': 0.9415},
#  'B08Y7MXFMK': {'neg': 0.085, 'neu': 0.768, 'pos': 0.147, 'compound': 0.9771},
#  'B086Q3QMFS': {'neg': 0.029, 'neu': 0.653, 'pos': 0.318, 'compound': 0.9707},
#  'B08498H13H': {'neg': 0.032, 'neu': 0.74, 'pos': 0.228, 'compound': 0.9972},
#  'B07LFQLKFZ': {'neg': 0.035, 'neu': 0.765, 'pos': 0.199, 'compound': 0.9652},
#  'B00LY17RHI': {'neg': 0.037, 'neu': 0.777, 'pos': 0.185, 'compound': 0.9998},
#  'B07W14CHV8': {'neg': 0.103, 'neu': 0.786, 'pos': 0.111, 'compound': 0.3206},
#  'B09F5Z694W': {'neg': 0.045, 'neu': 0.881, 'pos': 0.074, 'compound': 0.9784},
#  'B0B25LQQPC': {'neg': 0.034, 'neu': 0.832, 'pos': 0.134, 'compound': 0.9941},
#  'B01LYLJ99X': {'neg': 0.022, 'neu': 0.764, 'pos': 0.214, 'compound': 0.9332},
#  'B014SZPBM4': {'neg': 0.0, 'neu': 0.882, 'pos': 0.118, 'compound': 0.921},
#  'B08CZHGHKH': {'neg': 0.0, 'neu': 0.784, 'pos': 0.216, 'compound': 0.9859},
#  'B0B2RBP83P': {'neg': 0.061, 'neu': 0.83, 'pos': 0.109, 'compound': 0.9144},
#  'B078W65FJ7': {'neg': 0.083, 'neu': 0.752, 'pos': 0.165, 'compound': 0.9813},
#  'B08S74GTBT': {'neg': 0.03, 'neu': 0.883, 'pos': 0.088, 'compound': 0.9767},
#  'B07QMRHWJD': {'neg': 0.013, 'neu': 0.748, 'pos': 0.239, 'compound': 0.9942},
#  'B07W7Z6DVL': {'neg': 0.037, 'neu': 0.784, 'pos': 0.179, 'compound': 0.8875},
#  'B07WMS7TWB': {'neg': 0.068, 'neu': 0.831, 'pos': 0.101, 'compound': 0.9681},
#  'B00H47GVGY': {'neg': 0.0, 'neu': 0.758, 'pos': 0.242, 'compound': 0.9393},
#  'B07VX71FZP': {'neg': 0.0, 'neu': 0.646, 'pos': 0.354, 'compound': 0.9477},
#  'B07NCKMXVZ': {'neg': 0.08, 'neu': 0.741, 'pos': 0.178, 'compound': 0.9597},
#  'B0B61DSF17': {'neg': 0.021, 'neu': 0.854, 'pos': 0.125, 'compound': 0.8603},
#  'B07VQGVL68': {'neg': 0.105, 'neu': 0.757, 'pos': 0.137, 'compound': 0.4019},
#  'B01LWYDEQ7': {'neg': 0.043, 'neu': 0.776, 'pos': 0.181, 'compound': 0.9396},
#  'B07VNFP3C2': {'neg': 0.119, 'neu': 0.781, 'pos': 0.1, 'compound': -0.4497},
#  'B00LUGTJGO': {'neg': 0.0, 'neu': 0.935, 'pos': 0.065, 'compound': 0.2732},
#  'B01MQZ7J8K': {'neg': 0.081, 'neu': 0.601, 'pos': 0.317, 'compound': 0.9473},
#  'B01GFTEV5Y': {'neg': 0.0, 'neu': 0.963, 'pos': 0.037, 'compound': 0.4939},
#  'B00NW4UWN6': {'neg': 0.074, 'neu': 0.779, 'pos': 0.146, 'compound': 0.956},
#  'B01NCVJMKX': {'neg': 0.076, 'neu': 0.744, 'pos': 0.179, 'compound': 0.9973},
#  'B00O24PUO6': {'neg': 0.081, 'neu': 0.793, 'pos': 0.126, 'compound': 0.5913},
#  'B07GXPDLYQ': {'neg': 0.091, 'neu': 0.72, 'pos': 0.189, 'compound': 0.9396},
#  'B01C8P29N0': {'neg': 0.153, 'neu': 0.65, 'pos': 0.198, 'compound': 0.7317},
#  'B08KDBLMQP': {'neg': 0.0, 'neu': 0.889, 'pos': 0.111, 'compound': 0.9412},
#  'B078JDNZJ8': {'neg': 0.032, 'neu': 0.782, 'pos': 0.187, 'compound': 0.9941},
#  'B01M5F614J': {'neg': 0.103, 'neu': 0.836, 'pos': 0.061, 'compound': -0.8605},
#  'B083GKDRKR': {'neg': 0.01, 'neu': 0.834, 'pos': 0.156, 'compound': 0.9638},
#  'B097R2V1W8': {'neg': 0.054, 'neu': 0.784, 'pos': 0.162, 'compound': 0.9216},
#  'B07YR26BJ3': {'neg': 0.026, 'neu': 0.731, 'pos': 0.243, 'compound': 0.9829},
#  'B097R45BH8': {'neg': 0.031, 'neu': 0.763, 'pos': 0.206, 'compound': 0.9789},
#  'B09X5C9VLK': {'neg': 0.0, 'neu': 0.733, 'pos': 0.267, 'compound': 0.962},
#  'B01C8P29T4': {'neg': 0.062, 'neu': 0.736, 'pos': 0.202, 'compound': 0.9315},
#  'B00HVXS7WC': {'neg': 0.124, 'neu': 0.567, 'pos': 0.309, 'compound': 0.9286},
#  'B096YCN3SD': {'neg': 0.0, 'neu': 0.703, 'pos': 0.297, 'compound': 0.9538},
#  'B09LQH3SD9': {'neg': 0.031, 'neu': 0.797, 'pos': 0.172, 'compound': 0.9182},
#  'B09KNMLH4Y': {'neg': 0.063, 'neu': 0.792, 'pos': 0.145, 'compound': 0.9311},
#  'B00ABMASXG': {'neg': 0.045, 'neu': 0.859, 'pos': 0.096, 'compound': 0.6974},
#  'B07QDSN9V6': {'neg': 0.023, 'neu': 0.7, 'pos': 0.277, 'compound': 0.9823},
#  'B00YMJ0OI8': {'neg': 0.06, 'neu': 0.825, 'pos': 0.115, 'compound': 0.7615},
#  'B0B8XNPQPN': {'neg': 0.087, 'neu': 0.745, 'pos': 0.168, 'compound': 0.9727},
#  'B0814P4L98': {'neg': 0.0, 'neu': 0.591, 'pos': 0.409, 'compound': 0.9748},
#  'B008QTK47Q': {'neg': 0.051, 'neu': 0.819, 'pos': 0.13, 'compound': 0.9998},
#  'B088ZTJT2R': {'neg': 0.085, 'neu': 0.828, 'pos': 0.087, 'compound': 0.5014},
#  'B0BK1K598K': {'neg': 0.0, 'neu': 0.67, 'pos': 0.33, 'compound': 0.9843},
#  'B09Y5FZK9N': {'neg': 0.04, 'neu': 0.736, 'pos': 0.225, 'compound': 0.9889},
#  'B09J2SCVQT': {'neg': 0.033, 'neu': 0.776, 'pos': 0.192, 'compound': 0.9877},
#  'B00TDD0YM4': {'neg': 0.046, 'neu': 0.684, 'pos': 0.27, 'compound': 0.9773},
#  'B078KRFWQB': {'neg': 0.125, 'neu': 0.799, 'pos': 0.076, 'compound': -0.7187},
#  'B07SRM58TP': {'neg': 0.075, 'neu': 0.73, 'pos': 0.195, 'compound': 0.9984},
#  'B00EDJJ7FS': {'neg': 0.083, 'neu': 0.781, 'pos': 0.136, 'compound': 0.9963},
#  'B0832W3B7Q': {'neg': 0.0, 'neu': 0.831, 'pos': 0.169, 'compound': 0.9231},
#  'B07WNK1FFN': {'neg': 0.059, 'neu': 0.8, 'pos': 0.141, 'compound': 0.9962},
#  'B009P2LK08': {'neg': 0.018, 'neu': 0.92, 'pos': 0.062, 'compound': 0.6486},
#  'B07DGD4Z4C': {'neg': 0.096, 'neu': 0.746, 'pos': 0.159, 'compound': 0.8857},
#  'B07GMFY9QM': {'neg': 0.0, 'neu': 0.702, 'pos': 0.298, 'compound': 0.9844},
#  'B0BGPN4GGH': {'neg': 0.0, 'neu': 0.682, 'pos': 0.318, 'compound': 0.91},
#  'B0B2DZ5S6R': {'neg': 0.05, 'neu': 0.736, 'pos': 0.215, 'compound': 0.8845},
#  'B07S851WX5': {'neg': 0.039, 'neu': 0.709, 'pos': 0.252, 'compound': 0.994},
#  'B01MY839VW': {'neg': 0.0, 'neu': 0.76, 'pos': 0.24, 'compound': 0.934},
#  'B09LV1CMGH': {'neg': 0.044, 'neu': 0.836, 'pos': 0.12, 'compound': 0.7918},
#  'B01EY310UM': {'neg': 0.0, 'neu': 0.675, 'pos': 0.325, 'compound': 0.9707},
#  'B09NL7LBWT': {'neg': 0.034, 'neu': 0.747, 'pos': 0.219, 'compound': 0.995},
#  'B008YW8M0G': {'neg': 0.035, 'neu': 0.706, 'pos': 0.259, 'compound': 0.9822},
#  'B097R3XH9R': {'neg': 0.0, 'neu': 0.955, 'pos': 0.045, 'compound': 0.5233},
#  'B08TM71L54': {'neg': 0.022, 'neu': 0.855, 'pos': 0.123, 'compound': 0.987},
#  'B0BPBXNQQT': {'neg': 0.02, 'neu': 0.602, 'pos': 0.378, 'compound': 0.9929},
#  'B00W56GLOQ': {'neg': 0.021, 'neu': 0.78, 'pos': 0.199, 'compound': 0.9976},
#  'B0883KDSXC': {'neg': 0.0, 'neu': 0.667, 'pos': 0.333, 'compound': 0.7906},
#  'B078V8R9BS': {'neg': 0.023, 'neu': 0.834, 'pos': 0.144, 'compound': 0.9212},
#  'B08GSQXLJ2': {'neg': 0.057, 'neu': 0.849, 'pos': 0.094, 'compound': 0.882},
#  'B01M5B0TPW': {'neg': 0.0, 'neu': 0.829, 'pos': 0.171, 'compound': 0.9905},
#  'B082KVTRW8': {'neg': 0.0, 'neu': 0.755, 'pos': 0.245, 'compound': 0.9062},
#  'B08CFJBZRK': {'neg': 0.038, 'neu': 0.736, 'pos': 0.226, 'compound': 0.9611},
#  'B07H3WDC4X': {'neg': 0.038, 'neu': 0.809, 'pos': 0.152, 'compound': 0.9858},
#  'B09ZTZ9N3Q': {'neg': 0.095, 'neu': 0.809, 'pos': 0.096, 'compound': -0.4121},
#  'B083P71WKK': {'neg': 0.019, 'neu': 0.788, 'pos': 0.193, 'compound': 0.9386},
#  'B097R4D42G': {'neg': 0.029, 'neu': 0.766, 'pos': 0.205, 'compound': 0.9932},
#  'B07MKMFKPG': {'neg': 0.059, 'neu': 0.786, 'pos': 0.155, 'compound': 0.9993},
#  'B0949FPSFY': {'neg': 0.025, 'neu': 0.838, 'pos': 0.137, 'compound': 0.9865},
#  'B08F47T4X5': {'neg': 0.026, 'neu': 0.754, 'pos': 0.22, 'compound': 0.9679},
#  'B01M0505SJ': {'neg': 0.051, 'neu': 0.742, 'pos': 0.207, 'compound': 0.9072},
#  'B08D6RCM3Q': {'neg': 0.0, 'neu': 0.735, 'pos': 0.265, 'compound': 0.9743},
#  'B009P2LITG': {'neg': 0.0, 'neu': 0.775, 'pos': 0.225, 'compound': 0.9724},
#  'B00V9NHDI4': {'neg': 0.039, 'neu': 0.696, 'pos': 0.266, 'compound': 0.9841},
#  'B07WGPBXY9': {'neg': 0.0, 'neu': 0.721, 'pos': 0.279, 'compound': 0.9866},
#  'B00KRCBA6E': {'neg': 0.085, 'neu': 0.789, 'pos': 0.126, 'compound': 0.8687},
#  'B0B3X2BY3M': {'neg': 0.015, 'neu': 0.833, 'pos': 0.152, 'compound': 0.9553},
#  'B00F159RIK': {'neg': 0.0, 'neu': 0.685, 'pos': 0.315, 'compound': 0.9384},
#  'B08MV82R99': {'neg': 0.0, 'neu': 0.847, 'pos': 0.153, 'compound': 0.9285},
#  'B09VKWGZD7': {'neg': 0.083, 'neu': 0.801, 'pos': 0.116, 'compound': 0.9048},
#  'B009P2LK80': {'neg': 0.12, 'neu': 0.801, 'pos': 0.079, 'compound': -0.9552},
#  'B00A7PLVU6': {'neg': 0.0, 'neu': 0.748, 'pos': 0.252, 'compound': 0.9418},
#  'B0B25DJ352': {'neg': 0.03, 'neu': 0.679, 'pos': 0.291, 'compound': 0.9915},
#  'B013B2WGT6': {'neg': 0.027, 'neu': 0.834, 'pos': 0.14, 'compound': 0.9683},
#  'B097RJ867P': {'neg': 0.0, 'neu': 0.651, 'pos': 0.349, 'compound': 0.9976},
#  'B091V8HK8Z': {'neg': 0.078, 'neu': 0.784, 'pos': 0.138, 'compound': 0.3374},
#  'B071VNHMX2': {'neg': 0.025, 'neu': 0.811, 'pos': 0.165, 'compound': 0.9517},
#  'B08MVSGXMY': {'neg': 0.067, 'neu': 0.861, 'pos': 0.071, 'compound': 0.3612},
#  'B00H0B29DI': {'neg': 0.07, 'neu': 0.807, 'pos': 0.123, 'compound': 0.9977},
#  'B01GZSQJPA': {'neg': 0.099, 'neu': 0.756, 'pos': 0.146, 'compound': 0.6641},
#  ...}

# %%
vader = pd.DataFrame(res).T
vader = vader.reset_index().rename(columns={'index' : 'product_id'})

vader
# Out:
#       product_id    neg    neu    pos  compound
# 0     B07JW9H4J1  0.032  0.744  0.224    0.9033
# 1     B098NS6PVG  0.010  0.821  0.169    0.9853
# 2     B096MSW6CT  0.000  0.641  0.359    0.6808
# 3     B08HDJ86NZ  0.028  0.800  0.172    0.8316
# 4     B08CF3B7N1  0.116  0.719  0.165    0.9809
# ...          ...    ...    ...    ...       ...
# 1345  B08L7J3T31  0.016  0.763  0.221    0.9468
# 1346  B01M6453MB  0.122  0.714  0.164    0.7876
# 1347  B009P2LIL4  0.083  0.718  0.199    0.9698
# 1348  B00J5DYCCA  0.061  0.882  0.057   -0.2960
# 1349  B01486F4G6  0.007  0.847  0.146    0.9915
#
# [1350 rows x 5 columns]

# %%
merged = amazon_sales2.merge(vader, how="left")
merged
# Out:
#       product_id                                       product_name  \
# 0     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1     B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2     B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3     B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4     B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...          ...                                                ...
# 1459  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1460  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1461  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1462  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1463  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#       discounted_price  actual_price  discount_percentage  rating  \
# 0                399.0        1099.0                 0.64     4.2
# 1                199.0         349.0                 0.43     4.0
# 2                199.0        1899.0                 0.90     3.9
# 3                329.0         699.0                 0.53     4.2
# 4                154.0         399.0                 0.61     4.2
# ...                ...           ...                  ...     ...
# 1459             379.0         919.0                 0.59     4.0
# 1460            2280.0        3045.0                 0.25     4.1
# 1461            2219.0        3080.0                 0.28     3.6
# 1462            1399.0        1890.0                 0.26     4.0
# 1463            2863.0        3690.0                 0.22     4.3
#
#       rating_count            main_category                    sub_category  \
# 0          24269.0  Computers & Accessories       Accessories & Peripherals
# 1          43994.0  Computers & Accessories       Accessories & Peripherals
# 2           7928.0  Computers & Accessories       Accessories & Peripherals
# 3          94363.0  Computers & Accessories       Accessories & Peripherals
# 4          16905.0  Computers & Accessories       Accessories & Peripherals
# ...            ...                      ...                             ...
# 1459        1090.0           Home & Kitchen       Kitchen & Home Appliances
# 1460        4118.0           Home & Kitchen       Kitchen & Home Appliances
# 1461         468.0           Home & Kitchen  Heating, Cooling & Air Quality
# 1462        8031.0           Home & Kitchen  Heating, Cooling & Air Quality
# 1463        6987.0           Home & Kitchen       Kitchen & Home Appliances
#
#       price_gap rating_category    neg    neu    pos  compound
# 0         700.0   Above Average  0.032  0.744  0.224    0.9033
# 1         150.0   Above Average  0.010  0.821  0.169    0.9853
# 2        1700.0         Average  0.000  0.641  0.359    0.6808
# 3         370.0   Above Average  0.028  0.800  0.172    0.8316
# 4         245.0   Above Average  0.116  0.719  0.165    0.9809
# ...         ...             ...    ...    ...    ...       ...
# 1459      540.0   Above Average  0.016  0.763  0.221    0.9468
# 1460      765.0   Above Average  0.122  0.714  0.164    0.7876
# 1461      861.0         Average  0.083  0.718  0.199    0.9698
# 1462      491.0   Above Average  0.061  0.882  0.057   -0.2960
# 1463      827.0   Above Average  0.007  0.847  0.146    0.9915
#
# [1464 rows x 15 columns]

# %% [markdown]
# Let's see rating vs positive, negatifie, and neutral first

# %%
fig, ax = plt.subplots(3,1, figsize=(10,20))

sns.barplot(data=merged, x="rating", y="pos", ax=ax[0])
sns.barplot(data=merged, x="rating", y="neu", ax=ax[1])
sns.barplot(data=merged, x="rating", y="neg", ax=ax[2])

ax[0].set_title('Positive', fontweight = 'bold')
ax[1].set_title('Neutral', fontweight = 'bold')
ax[2].set_title('Negative', fontweight = 'bold')

plt.show()

# %% [markdown]
# While analyzing customer reviews, it was discovered that only one product had a rating of 2.0, and furthermore, this product did not receive any negative sentiment scores. Therefore, it may not be appropriate to rely solely on rating as an indicator of customer sentiment. To address this issue, an alternative visualization was proposed, which groups the data into rating categories.
# Upon examination of the sentiment scores across different rating categories, it was found that the positivity scores increase as the rating of the product increases. In contrast, the scores for neutral reviews remained consistent across most rating categories, with a slight dip in sentiment score at a rating of 4.8. Finally, negative sentiment scores were found to be lowest for products with the highest rating scores.

# %%
fig, ax = plt.subplots(3,1, figsize=(10,20))

sns.barplot(data=merged, x='rating_category', y='pos', ax=ax[0])
sns.barplot(data=merged, x='rating_category', y='neu', ax=ax[1])
sns.barplot(data=merged, x='rating_category', y='neg', ax=ax[2])

ax[0].set_title('Positive', fontweight = 'bold')
ax[1].set_title('Neutral', fontweight = 'bold')
ax[2].set_title('Negative', fontweight = 'bold')

plt.show()

# %%
sentiment_score = merged[['pos', 'neu', 'neg', 'compound']]
sentiment_score.describe()[1:8]
# Out:
#            pos       neu       neg  compound
# mean  0.183488  0.770603  0.045915  0.820152
# std   0.074160  0.071685  0.037692  0.367998
# min   0.000000  0.465000  0.000000 -0.982100
# 25%   0.132000  0.727000  0.020000  0.870450
# 50%   0.173500  0.780000  0.041000  0.961500
# 75%   0.225000  0.819250  0.064000  0.988675
# max   0.500000  1.000000  0.413000  0.999900

# %% [markdown]
# The overall reviews on this amazon sales are positive with the mean of 82%

# %% [markdown]
# ## Vader Reviews

# %%
#Remove duplicate rows from 'amazon_reviews'
amazon_reviews = amazon_reviews.drop_duplicates(subset='product_id')

# Remove duplicate rows from 'amazon_sales2'
amazon_sales2 = amazon_sales2.drop_duplicates(subset='product_id')

# Perform the merge based on 'product_id'
merged3 = amazon_reviews.merge(amazon_sales2[['product_id', 'rating', 'rating_category']], on='product_id', how='left')
merged3 = merged3.merge(vader, how="left")
merged3
# Out:
#       product_id                                       review_title  \
# 0     B07JW9H4J1  Satisfied,Charging is really fast,Value for mo...
# 1     B098NS6PVG  A Good Braided Cable for Your Type C Device,Go...
# 2     B096MSW6CT  Good speed for earlier versions,Good Product,W...
# 3     B08HDJ86NZ  Good product,Good one,Nice,Really nice product...
# 4     B08CF3B7N1  As good as original,Decent,Good one for second...
# ...          ...                                                ...
# 1345  B08L7J3T31  Received the product without spanner,Excellent...
# 1346  B01M6453MB  ok,everything was good couldn't return bcoz I ...
# 1347  B009P2LIL4  very good,Work but front melt after 2 month,Go...
# 1348  B00J5DYCCA  Fan Speed is slow,Good quality,Good product,go...
# 1349  B01486F4G6  Works perfect,Ok good product,Nice Product. Re...
#
#                                          review_content  rating  \
# 0     Looks durable Charging is fine tooNo complains...     4.2
# 1     I ordered this cable to connect my phone to An...     4.0
# 2     Not quite durable and sturdy,https://m.media-a...     3.9
# 3     Good product,long wire,Charges good,Nice,I bou...     4.2
# 4     Bought this instead of original apple, does th...     4.2
# ...                                                 ...     ...
# 1345  I received product without spanner,Excellent p...     4.0
# 1346  ok,got everything as mentioned but the measuri...     4.1
# 1347  plastic but cool body ,u have to find sturdy s...     3.6
# 1348  I have installed this in my kitchen working fi...     4.0
# 1349  It does it job perfectly..only issue is temp c...     4.3
#
#      rating_category    neg    neu    pos  compound
# 0      Above Average  0.032  0.744  0.224    0.9033
# 1      Above Average  0.010  0.821  0.169    0.9853
# 2            Average  0.000  0.641  0.359    0.6808
# 3      Above Average  0.028  0.800  0.172    0.8316
# 4      Above Average  0.116  0.719  0.165    0.9809
# ...              ...    ...    ...    ...       ...
# 1345   Above Average  0.016  0.763  0.221    0.9468
# 1346   Above Average  0.122  0.714  0.164    0.7876
# 1347         Average  0.083  0.718  0.199    0.9698
# 1348   Above Average  0.061  0.882  0.057   -0.2960
# 1349   Above Average  0.007  0.847  0.146    0.9915
#
# [1350 rows x 9 columns]

# %%
avg_pos = merged3[merged3["rating_category"] == "Average"].sort_values("pos", ascending=False)
avg_pos["review_content"].values[0]
# Out:
# "1.build quality is very good2.sound quality is good3.comfortable to wear4.it is ok for calls but other person will hear your voice very heavy and sound like old radio or something5.in this price range its a very good earbuds,Can't find better than this under 1KBEST IN THIS PRICE RANGE !!,,Vry nice one of this range  ..,All over best earbuds . In this price range:)I m really happy 😊,I love to this product,This product is really good as for the money, sensor is good, lights look cool, bass is good, battery backup is also good. Best thing is its Bluetooth connectivity which is super fast. Only limitation is that it connects to only 1 device at a time. Highly Recommended.,"

# %%
excellent_pos = merged3[merged3["rating_category"] == "Average"].sort_values("neg", ascending=False)
excellent_pos["review_content"].values[0]
# Out:
# "Overall I liked the productBut disappointed with this broken item,It is useful only small cuts like kids clothes,,Today I get the product. In the accessory box the pin and saftypins are in that condition.,It's not good for beginners.It's not that simple to stich.. Sometimes the machine will stuck in the middle of stitching....,Sewing machine is really good . Easy to use and good for beginners.,Overall good item for this price. Light weight and suitable for alteration work...,"

# %%
blw_avg = merged3[merged3["rating_category"] == "Below Average"].sort_values("neg", ascending=False)
blw_avg["review_content"].values[0]
# Out:
# 'I liked that it is so convenient to carry,Waste of money. Defective product, cheap quality. doesn’t blend at all,https://m.media-amazon.com/images/I/71IVsjyZ13L._SY88.jpg,First charge problemSecond motor proble,https://m.media-amazon.com/images/I/61aXXxIxPwL._SY88.jpg'
